# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import simpy

# %%
# Global variables
# Copied from the MDP code

# Queue size
MAX_QUEUE_SIZE = 20

# Arrival average of customers per unit time (Poisson process)
ARRIVAL_SIMPLE = 12
ARRIVAL_COMPLEX = 5

# Service rate of agents for each query types (Exponential distribution)
## Agent 1
SERVICE_SIMPLE_1 = 12
SERVICE_COMPLEX_1 = 3
## Agent 2
SERVICE_SIMPLE_2 = 6
SERVICE_COMPLEX_2 = 5

# %%
# Data collection lists
waiting_times = []
agent_utilisations = {'Agent 1 Simple': 0,
                      'Agent 1 Complex': 0,
                      'Agent 2 Simple': 0,
                      'Agent 2 Complex': 0,
                      'Dropped Calls': 0}
queue_lengths = []
queue_length_times = []

# %%
def get_policy_decision(policy_simple, policy_complex, q1, q2, call_type):
    """
    Get the policy decision based on the current state.
    returns the action to take (0 to agent1 or 1 to agent2).
    """
    
    # Ensure we don't exceed the maximum queue size
    q1 = min(q1, MAX_QUEUE_SIZE)
    q2 = min(q2, MAX_QUEUE_SIZE)
    
    if call_type == 'Simple':
        return policy_simple[q1, q2]
    else:
        return policy_complex[q1, q2]


def handle_call(env, policy_simple, policy_complex, call_type, agent1, agent2):
    """Handle the call from arrival to completion."""
    arrival_time = env.now
    
    # Get current queue sizes
    q1 = len(agent1.queue) + (1 if agent1.count > 0 else 0)
    q2 = len(agent2.queue) + (1 if agent2.count > 0 else 0)
    
    # Check if queues are full
    q1_full = q1 >= MAX_QUEUE_SIZE
    q2_full = q2 >= MAX_QUEUE_SIZE
    
    decision = get_policy_decision(policy_simple, policy_complex, q1, q2, call_type)
    
    # Route to selected queue if not full
    if decision == 0 and not q1_full:
        queue = agent1
    elif decision == 1 and not q2_full:
        queue = agent2
    elif not q1_full:
        queue = agent1
        decision = 0
    elif not q2_full:
        queue = agent2
        decision = 1
    else:
        # Both queues are full, drop the call
        agent_utilisations['Dropped Calls'] += 1
        print(f'{call_type} call dropped at {env.now}')
        return
    
    # Get into the queue and request service
    with queue.request() as req:
        yield req
        
        # Call is being served
        service_start_time = env.now
        waiting_time = service_start_time - arrival_time
        
        # Determine service time based on agent and call type
        if decision == 0:
            service_rate = SERVICE_SIMPLE_1 if call_type == 'Simple' else SERVICE_COMPLEX_1
        else:
            service_rate = SERVICE_SIMPLE_2 if call_type == 'Simple' else SERVICE_COMPLEX_2
            
        service_time = random.expovariate(service_rate)
        
        # Serve the call
        yield env.timeout(service_time)
        
        # Call completed
        completion_time = env.now
        total_time = completion_time - arrival_time
        
        # Record statistics
        waiting_times.append({
            'call_type': call_type,
            'queue': decision + 1,
            'arrival_time': arrival_time,
            'waiting_time': waiting_time,
            'service_time': service_time,
            'total_time': total_time
        })
        
        # Update agent utilisation
        agent_utilisations[f'Agent {decision + 1} {call_type}'] += 1

def simple_call_generator(env, policy_simple, policy_complex, queue1, queue2):
    """Generate simple calls according to a Poisson process."""
    while True:
        interarrival_time = random.expovariate(ARRIVAL_SIMPLE)
        yield env.timeout(interarrival_time)
        
        # Create a new call
        env.process(handle_call(env, policy_simple, policy_complex, 'Simple', queue1, queue2))
        
def complex_call_generator(env, policy_simple, policy_complex, queue1, queue2):
    """Generate complex calls according to a Poisson process."""
    while True:
        interarrival_time = random.expovariate(ARRIVAL_COMPLEX)
        yield env.timeout(interarrival_time)
        
        # Create a new call
        env.process(handle_call(env, policy_simple, policy_complex, 'Complex', queue1, queue2))
        
def record_queue_length(env, queue1, queue2):
    """Record the lengths of the queues at regular intervals."""
    while True:
        # Queue length includes the customer being served
        queue1_len = len(queue1.queue) + (1 if queue1.count > 0 else 0)
        queue2_len = len(queue2.queue) + (1 if queue2.count > 0 else 0)
        
        queue_lengths.append((
            queue1_len,
            queue2_len,
            env.now
        ))
        queue_length_times.append(env.now)
        
        yield env.timeout(0.1)

# %%
# Get results from the simulation
def get_results():
    """Compute and return the results of the simulation."""
    # Convert waiting times to DataFrame
    df_waiting = pd.DataFrame(waiting_times)
    
    # Calculate average metrics
    avg_waiting_time = df_waiting['waiting_time'].mean() if not df_waiting.empty else 0
    avg_service_time = df_waiting['service_time'].mean() if not df_waiting.empty else 0
    avg_total_time = df_waiting['total_time'].mean() if not df_waiting.empty else 0
    
    # Calculate metrics by call type
    avg_waiting_by_type = df_waiting.groupby('call_type')['waiting_time'].mean().to_dict() if not df_waiting.empty else {}
    avg_service_by_type = df_waiting.groupby('call_type')['service_time'].mean().to_dict() if not df_waiting.empty else {}
    
    # Calculate metrics by queue
    avg_waiting_by_queue = df_waiting.groupby('queue')['waiting_time'].mean().to_dict() if not df_waiting.empty else {}
    
    # Extract queue lengths and times
    queue_data = pd.DataFrame(queue_lengths, columns=['Queue 1 Length', 'Queue 2 Length', 'Time'])
    avg_queue_length = [queue_data['Queue 1 Length'].mean(), queue_data['Queue 2 Length'].mean()]
    
    # Calculate call volumes
    completed_calls = agent_utilisations['Agent 1 Simple'] + agent_utilisations['Agent 1 Complex'] + \
                    agent_utilisations['Agent 2 Simple'] + agent_utilisations['Agent 2 Complex']
    total_calls = completed_calls + agent_utilisations['Dropped Calls']
    
    call_counts = {
        'total': total_calls,
        'completed': completed_calls,
        'simple': agent_utilisations['Agent 1 Simple'] + agent_utilisations['Agent 2 Simple'],
        'complex': agent_utilisations['Agent 1 Complex'] + agent_utilisations['Agent 2 Complex'],
        'agent1': agent_utilisations['Agent 1 Simple'] + agent_utilisations['Agent 1 Complex'],
        'agent2': agent_utilisations['Agent 2 Simple'] + agent_utilisations['Agent 2 Complex'],
        'dropped': agent_utilisations['Dropped Calls'],
        'drop_rate': agent_utilisations['Dropped Calls'] / total_calls if total_calls > 0 else 0
        }
    
    # Combine all results into a dictionary
    results = {
        'call_counts': call_counts,
        'avg_waiting_time': avg_waiting_time,
        'avg_service_time': avg_service_time,
        'avg_total_time': avg_total_time,
        'avg_waiting_by_type': avg_waiting_by_type,
        'avg_service_by_type': avg_service_by_type,
        'avg_waiting_by_queue': avg_waiting_by_queue,
        'avg_queue_length': avg_queue_length,
        'waiting_times_df': df_waiting,
        'queue_data': queue_data
    }
    
    return results
    

# Run the simulation
def run_simulation(policy_simple, policy_complex, sim_time=1000):
    """Run the simulation for a given time."""
    env = simpy.Environment()
    
    # Set random seed for reproducibility
    np.random.seed(42)
    random.seed(42)
    
    # Reset global variables
    global waiting_times, agent_utilisations, queue_lengths, queue_length_times
    waiting_times = []
    agent_utilisations = {'Agent 1 Simple': 0,
                            'Agent 1 Complex': 0,
                            'Agent 2 Simple': 0,
                            'Agent 2 Complex': 0,
                            'Dropped Calls': 0}
    queue_lengths = []
    queue_length_times = []
    
    agent1 = simpy.Resource(env, capacity=1)
    agent2 = simpy.Resource(env, capacity=1)
    
    # Start call generators
    env.process(simple_call_generator(env, policy_simple, policy_complex, agent1, agent2))
    env.process(complex_call_generator(env, policy_simple, policy_complex, agent1, agent2))
    
    # Start queue length recorder
    env.process(record_queue_length(env, agent1, agent2))
    
    # Run the simulation
    env.run(until=sim_time)
    
    # Get results
    results = get_results()
    return results
    
# Plotting functions

def plot_policies(policy_simple, policy_complex):
    """Plot the policies for simple and complex calls."""
    fig, axes = plt.subplots(1, 2, figsize=(12, 5))
    
    sns.heatmap(policy_simple, cmap="YlGnBu", annot=True, fmt=".0f", cbar=False, ax=axes[0])
    axes[0].set_title('Policy for Simple Calls')
    axes[0].set_xlabel('Queue 2 Size')
    axes[0].set_ylabel('Queue 1 Size')
    
    sns.heatmap(policy_complex, cmap="YlOrBr", annot=True, fmt=".0f", cbar=False, ax=axes[1])
    axes[1].set_title('Policy for Complex Calls')
    axes[1].set_xlabel('Queue 2 Size')
    axes[1].set_ylabel('Queue 1 Size')
    
    plt.tight_layout()
    plt.show()
    
def plot_queue_length_over_time(results):
    """Plot the queue lengths over time."""
    queue_data = results['queue_data']
    
    plt.figure(figsize=(12, 6))
    plt.plot(queue_data['Time'], queue_data['Queue 1 Length'], label='Queue 1 Length', color='blue')
    plt.plot(queue_data['Time'], queue_data['Queue 2 Length'], label='Queue 2 Length', color='orange')
    
    plt.title('Queue Lengths Over Time')
    plt.xlabel('Time')
    plt.ylabel('Queue Length')
    plt.legend()
    plt.grid()
    plt.show()
    
def plot_waiting_times_by_queue(results):
    """Plot the average waiting times by queue."""
    df_waiting = results['waiting_times_df']
    
    plt.figure(figsize=(8, 5))
    sns.barplot(data=df_waiting, x='queue', y='waiting_time')
    
    plt.title('Average Waiting Time by Queue')
    plt.xlabel('Queue')
    plt.ylabel('Average Waiting Time')
    plt.grid()
    plt.show()

# %%
# Load optimal policy from the pickle file
# with open('policy_simple.pkl', 'rb') as f:
#     opt_simple_policy = pickle.load(f)
# with open('policy_complex.pkl', 'rb') as f:
#     opt_complex_policy = pickle.load(f)
    
with open('pickles/policy_simple_withdrop.pkl', 'rb') as f:
    opt_simple_policy = pickle.load(f)
with open('pickles/policy_complex_withdrop.pkl', 'rb') as f:
    opt_complex_policy = pickle.load(f)

# Set runtime for the simulation
RUNTIME = 24  # Simulate for 24 hours

# Plot the policies
plot_policies(opt_simple_policy, opt_complex_policy)

# %%
opt_simple_policy, opt_complex_policy

# %%
# Run the simulation
results = run_simulation(opt_simple_policy, opt_complex_policy, sim_time=RUNTIME)

# %%
# Plot the results

plot_queue_length_over_time(results)
plot_waiting_times_by_queue(results)

# %%
# Create another policy for comparison
# Route calls to the queue with the least number of calls
# If both queues size are equal, route simple calls to queue 1 and complex calls to queue 2
alt_simple_policy = np.zeros((MAX_QUEUE_SIZE + 1, MAX_QUEUE_SIZE + 1), dtype=int)
for i in range(MAX_QUEUE_SIZE + 1):
    for j in range(MAX_QUEUE_SIZE + 1):
        if i < j:
            alt_simple_policy[i, j] = 0  # Route to queue 1
        elif i > j:
            alt_simple_policy[i, j] = 1  # Route to queue 2
            
alt_complex_policy = np.ones((MAX_QUEUE_SIZE + 1, MAX_QUEUE_SIZE + 1), dtype=int)
for i in range(MAX_QUEUE_SIZE + 1):
    for j in range(MAX_QUEUE_SIZE + 1):
        if i < j:
            alt_complex_policy[i, j] = 0  # Route to queue 1
        elif i > j:
            alt_complex_policy[i, j] = 1  # Route to queue 2
            
# Plot the new policies
plot_policies(alt_simple_policy, alt_complex_policy)

# %%
# Run the simulation
results_2 = run_simulation(alt_simple_policy, alt_complex_policy, sim_time=RUNTIME)
# Out:
# Complex call dropped at 19.03035778530023
# Simple call dropped at 19.146538894356276
# Simple call dropped at 19.154093081194628
# Simple call dropped at 19.77379086317315
# Complex call dropped at 19.800624026854397
# Complex call dropped at 19.818524295248732
# Simple call dropped at 20.127854394511637
# Simple call dropped at 20.200455329366804
# Simple call dropped at 20.253876090926106
# Simple call dropped at 20.316958263115865
# Simple call dropped at 20.363146747972362
# Simple call dropped at 20.482101036870137
# Simple call dropped at 20.745799429720975
# Simple call dropped at 20.76378421519112
# Simple call dropped at 20.786480122290747

# %%
# Plot the results

plot_queue_length_over_time(results_2)
plot_waiting_times_by_queue(results_2)

# %%
# Simulate for a week (168 hours)

results_week = run_simulation(opt_simple_policy, opt_complex_policy, sim_time=168)
# Plot the results for the week
plot_queue_length_over_time(results_week)
plot_waiting_times_by_queue(results_week)
# Out:
# Simple call dropped at 58.92873572328166
# Simple call dropped at 61.10431993651821
# Complex call dropped at 62.03679002176498
# Simple call dropped at 70.08678192751795
# Complex call dropped at 70.2421254556151
# Simple call dropped at 71.71912536678859
# Simple call dropped at 71.92744518069263
# Simple call dropped at 71.96737994582135
# Simple call dropped at 71.97983619830919
# Simple call dropped at 72.00969389369412
# Complex call dropped at 74.68512068352389
# Simple call dropped at 74.70801140008734
# Simple call dropped at 74.73296153672273
# Simple call dropped at 75.01760554732678
# Simple call dropped at 75.5335142498858
# Simple call dropped at 75.7262283112565
# Simple call dropped at 75.74077122468715
# Simple call dropped at 75.8091576681192
# Simple call dropped at 76.67867179898712
# Complex call dropped at 76.70213925445444
# Complex call dropped at 76.89427279082899
# Simple call dropped at 77.03223470368492
# Simple call dropped at 77.25939931982278
# Complex call dropped at 79.16577199910986
# Simple call dropped at 79.25134841287945
# Simple call dropped at 79.27573549847052
# Simple call dropped at 79.40214977317576
# Complex call dropped at 79.43443605875125
# Simple call dropped at 80.10517355405518
# Simple call dropped at 80.20873153605615
# Complex call dropped at 80.41545286046393
# Simple call dropped at 81.903612824993
# Complex call dropped at 81.95910069031086
# Simple call dropped at 82.02066534685707
# Simple call dropped at 82.06992039752434
# Simple call dropped at 82.10124812499713
# Simple call dropped at 82.39591947372071
# Complex call dropped at 82.48092381282363
# Simple call dropped at 82.48340946355786
# Simple call dropped at 82.5902169157039
# Complex call dropped at 82.59692302244791
# Complex call dropped at 82.6297503948815
# Simple call dropped at 82.67263996609465
# Simple call dropped at 83.33535081974243
# Simple call dropped at 83.5255112848696
# Simple call dropped at 83.53547973026467
# Complex call dropped at 83.54363774744054
# Simple call dropped at 83.91009175970841
# Complex call dropped at 84.1499472213368
# Complex call dropped at 84.17205976404503
# Complex call dropped at 84.18453462703495
# Simple call dropped at 84.51900282302742
# Simple call dropped at 84.65655056283131
# Complex call dropped at 84.7519720016572
# Simple call dropped at 84.84531266066452
# Simple call dropped at 84.85282579030054
# Simple call dropped at 84.90032712053508
# Simple call dropped at 84.95065932824673
# Complex call dropped at 85.01380783649797
# Simple call dropped at 85.02887759305138
# Complex call dropped at 85.11325502498639
# Simple call dropped at 85.1416782971951
# Simple call dropped at 85.24242696750491
# Simple call dropped at 85.25733750781365
# Complex call dropped at 85.67090610586477
# Simple call dropped at 85.73633060293048
# Simple call dropped at 86.05177923061008
# Complex call dropped at 86.05188985939283
# Complex call dropped at 86.06089726312592
# Simple call dropped at 86.53157382901955
# Simple call dropped at 86.56393349732093
# Complex call dropped at 86.56707584597909
# Simple call dropped at 86.61554861005965
# Simple call dropped at 89.76247779370637
# Simple call dropped at 89.76348020888585
# Complex call dropped at 89.90948269628704
# Simple call dropped at 89.91132599484553
# Simple call dropped at 89.92299970464323
# Simple call dropped at 90.55874566711674
# Simple call dropped at 90.56123946972552
# Simple call dropped at 115.69728537757436
# Simple call dropped at 115.92615494354453
# Complex call dropped at 115.9297982911373
# Complex call dropped at 115.93636624182129
# Complex call dropped at 117.51394803239752
# Simple call dropped at 117.53074180099897
# Complex call dropped at 117.54732510647504
# Simple call dropped at 118.94621826023211
# Simple call dropped at 118.97392167399188
# Simple call dropped at 119.21499142448735
# Simple call dropped at 119.35029323417223
# Complex call dropped at 119.43469063627411
# Simple call dropped at 119.45955332585487
# Simple call dropped at 119.47481963500576
# Simple call dropped at 119.73564153923576
# Simple call dropped at 119.79998619848175
# Simple call dropped at 119.80059933073169
# Simple call dropped at 119.80624212236744
# Simple call dropped at 120.59392906151945
# Simple call dropped at 120.61886903463815
# Simple call dropped at 120.70707873470901
# Simple call dropped at 120.70849833868368
# Complex call dropped at 120.71534320382672
# Complex call dropped at 120.8684155525066
# Simple call dropped at 120.88199489877573
# Simple call dropped at 120.95540680922323
# Simple call dropped at 121.19416298313779
# Simple call dropped at 121.23605581998443
# Simple call dropped at 121.32613406016476
# Simple call dropped at 121.33835273622152
# Simple call dropped at 121.3796798031809
# Complex call dropped at 121.43621729335125
# Simple call dropped at 121.71591084643494
# Simple call dropped at 121.75482892291434
# Complex call dropped at 121.93830513099364
# Simple call dropped at 122.00358651975992
# Simple call dropped at 122.09806617179783
# Complex call dropped at 122.20417135037484
# Simple call dropped at 122.21302482313764
# Complex call dropped at 122.31059975827615
# Simple call dropped at 122.31417107853733
# Simple call dropped at 122.46419490499598
# Simple call dropped at 122.74108732572498
# Simple call dropped at 122.76970482420369
# Simple call dropped at 122.77551640430768
# Complex call dropped at 122.78296410492345
# Simple call dropped at 122.7841301689638
# Simple call dropped at 122.83978439167741
# Simple call dropped at 122.87326342676728
# Simple call dropped at 122.88469781120587
# Complex call dropped at 123.73370698964888
# Simple call dropped at 123.79929789266606
# Simple call dropped at 123.83138368982614
# Simple call dropped at 123.8379165248843
# Simple call dropped at 123.8394836936208
# Complex call dropped at 123.88841279486287
# Complex call dropped at 123.8947510212589
# Simple call dropped at 123.89845101499925
# Simple call dropped at 124.13904394538295
# Simple call dropped at 125.36554951492954
# Simple call dropped at 125.83951609739877
# Simple call dropped at 125.90501863442405
# Simple call dropped at 125.92093352623286
# Simple call dropped at 126.06988514929138
# Simple call dropped at 126.10922947780533
# Simple call dropped at 126.6018736036556
# Simple call dropped at 126.74429301070631
# Simple call dropped at 126.74796823698509
# Complex call dropped at 127.11897763509107
# Simple call dropped at 127.1622985303244
# Simple call dropped at 128.2948722130896
# Complex call dropped at 128.31456794449906
# Simple call dropped at 128.3165970286817
# Simple call dropped at 129.10369818020473
# Complex call dropped at 129.14082101371736
# Complex call dropped at 130.96029225087818
# Complex call dropped at 131.02502536711881
# Complex call dropped at 131.21149079724398
# Complex call dropped at 131.25475546788135
# Simple call dropped at 131.30332098264284
# Complex call dropped at 131.3152760365091
# Complex call dropped at 131.33778998141915
# Simple call dropped at 131.34688664357904
# Complex call dropped at 131.35281789126495
# Simple call dropped at 131.37592804332903
# Simple call dropped at 131.51128291068758
# Simple call dropped at 131.91272070498684
# Complex call dropped at 131.94036893202806
# Simple call dropped at 131.9840054086722
# Simple call dropped at 133.94567288391224
# Simple call dropped at 134.0696846347731
# Simple call dropped at 134.1245466396961
# Complex call dropped at 134.39740943148195
# Complex call dropped at 135.6818900077024
# Simple call dropped at 135.74688320263527
# Simple call dropped at 137.6875543493056
# Complex call dropped at 137.68813010225125
# Simple call dropped at 137.69304751862134
# Complex call dropped at 138.11001291733973
# Simple call dropped at 138.13307983219872
# Complex call dropped at 138.13815913515313
# Complex call dropped at 138.14395661462012
# Simple call dropped at 138.28502651789898
# Complex call dropped at 138.49112903545202
# Simple call dropped at 138.52463336851056
# Simple call dropped at 139.00336890057628
# Simple call dropped at 139.17927502997685
# Simple call dropped at 139.47894337580283
# Simple call dropped at 139.51855929343654
# Simple call dropped at 139.566809383137
# Simple call dropped at 139.78349674502488
# Simple call dropped at 139.8966963090352
# Simple call dropped at 140.14375879467775
# Complex call dropped at 140.16416529535667
# Simple call dropped at 140.16989286088807
# Simple call dropped at 142.10147806620634
# Simple call dropped at 142.3172208850213
# Simple call dropped at 143.97736658466516
# Complex call dropped at 144.13985193294846
# Simple call dropped at 145.1176824851189
# Complex call dropped at 145.1236129389953
# Simple call dropped at 145.2025022468932
# Complex call dropped at 145.21223492187823
# Simple call dropped at 145.25365388593033
# Simple call dropped at 146.40307355345928
# Simple call dropped at 146.5644070844705
# Simple call dropped at 146.566235443587
# Simple call dropped at 146.7100382995281
# Complex call dropped at 147.35206418867716
# Simple call dropped at 147.4780790744098
# Complex call dropped at 147.58603973029668
# Simple call dropped at 147.6887514319728
# Complex call dropped at 148.07708643489806
# Simple call dropped at 148.11791211590608
# Simple call dropped at 148.18693017057296
# Complex call dropped at 148.3815268016417
# Complex call dropped at 148.39164048109427
# Simple call dropped at 148.5027557680334
# Simple call dropped at 148.5148287994595
# Complex call dropped at 148.52147489970318
# Simple call dropped at 148.60130061266204
# Simple call dropped at 148.68105932024508
# Simple call dropped at 148.6872543184029
# Simple call dropped at 149.44948493636116
# Simple call dropped at 149.4541584027111
# Complex call dropped at 149.7832183428271
# Simple call dropped at 149.84501796066655
# Simple call dropped at 149.85484886021973
# Simple call dropped at 150.0489495032573
# Simple call dropped at 150.06164874383364
# Simple call dropped at 150.25610951056683
# Complex call dropped at 150.28172865036115
# Simple call dropped at 153.65565755649035
# Simple call dropped at 153.6650669545398
# Simple call dropped at 153.68208830178637
# Simple call dropped at 153.82773736198524
# Simple call dropped at 154.10491605572014
# Complex call dropped at 154.14422543489812
# Simple call dropped at 154.68999037279065
# Complex call dropped at 157.53082931351912
# Complex call dropped at 157.5383117621824
# Simple call dropped at 164.47398967088998
# Simple call dropped at 164.48534559960618
# Simple call dropped at 164.49439758677178

# %%
results_week_2 = run_simulation(alt_simple_policy, alt_complex_policy, sim_time=168)
# Plot the results for the week
plot_queue_length_over_time(results_week_2)
plot_waiting_times_by_queue(results_week_2)
# Out:
# Complex call dropped at 19.03035778530023
# Simple call dropped at 19.146538894356276
# Simple call dropped at 19.154093081194628
# Simple call dropped at 19.77379086317315
# Complex call dropped at 19.800624026854397
# Complex call dropped at 19.818524295248732
# Simple call dropped at 20.127854394511637
# Simple call dropped at 20.200455329366804
# Simple call dropped at 20.253876090926106
# Simple call dropped at 20.316958263115865
# Simple call dropped at 20.363146747972362
# Simple call dropped at 20.482101036870137
# Simple call dropped at 20.745799429720975
# Simple call dropped at 20.76378421519112
# Simple call dropped at 20.786480122290747
# Simple call dropped at 36.90653580577404
# Complex call dropped at 37.02596517974087
# Simple call dropped at 37.1056456113894
# Simple call dropped at 37.24283000715402
# Simple call dropped at 37.38500473454682
# Simple call dropped at 37.4664562050324
# Simple call dropped at 37.970585322199085
# Simple call dropped at 37.99077205965377
# Simple call dropped at 38.218415616279366
# Simple call dropped at 38.300288081087864
# Simple call dropped at 38.56219565443762
# Complex call dropped at 38.56876127017257
# Simple call dropped at 38.57449671320188
# Complex call dropped at 38.76650939738257
# Complex call dropped at 38.775154010164485
# Complex call dropped at 38.7789378871219
# Simple call dropped at 38.96768285553645
# Simple call dropped at 39.66161122048385
# Complex call dropped at 39.791581957338956
# Complex call dropped at 39.84548984699352
# Complex call dropped at 39.877158723482
# Simple call dropped at 39.910550605429904
# Complex call dropped at 39.92110654479165
# Simple call dropped at 39.98740945976933
# Complex call dropped at 40.2067093093961
# Simple call dropped at 40.250024038136274
# Simple call dropped at 40.36894821755775
# Complex call dropped at 40.524759415168475
# Complex call dropped at 40.53890534632523
# Simple call dropped at 40.70049577058736
# Simple call dropped at 40.707148657858816
# Complex call dropped at 41.143241701386145
# Simple call dropped at 41.21660736885031
# Complex call dropped at 41.22082375032044
# Simple call dropped at 41.221929926430334
# Complex call dropped at 41.24267556630814
# Complex call dropped at 42.13569771797818
# Complex call dropped at 42.20978929890696
# Complex call dropped at 42.30432812592753
# Simple call dropped at 42.32197875035894
# Simple call dropped at 42.67335649546426
# Simple call dropped at 42.71088601379203
# Simple call dropped at 42.727450316108175
# Complex call dropped at 42.72817029610641
# Simple call dropped at 42.74753728549489
# Simple call dropped at 43.59162984411616
# Complex call dropped at 43.80206163608718
# Simple call dropped at 44.07021190108961
# Simple call dropped at 44.11030026989447
# Simple call dropped at 44.32665609220203
# Simple call dropped at 44.35062995508366
# Simple call dropped at 44.503428390018826
# Simple call dropped at 44.51244856862566
# Complex call dropped at 44.6346693343154
# Simple call dropped at 44.668290520240234
# Simple call dropped at 44.69625392621719
# Complex call dropped at 45.22960491944239
# Complex call dropped at 45.235323407684945
# Simple call dropped at 45.67805112793353
# Complex call dropped at 45.770602181054315
# Simple call dropped at 45.779934387911126
# Simple call dropped at 45.804568721465415
# Simple call dropped at 45.92265306567239
# Complex call dropped at 45.94628106064442
# Complex call dropped at 46.01794523292695
# Complex call dropped at 46.041444874611905
# Simple call dropped at 46.04724487377681
# Simple call dropped at 46.51135283237611
# Complex call dropped at 46.512530024370136
# Simple call dropped at 46.59549428246308
# Simple call dropped at 46.61987436327121
# Simple call dropped at 46.62123899510961
# Simple call dropped at 47.42635253563236
# Simple call dropped at 47.80231210831761
# Simple call dropped at 47.81338974014836
# Simple call dropped at 47.851631092181776
# Simple call dropped at 48.422161099428266
# Complex call dropped at 48.580909847660855
# Complex call dropped at 48.59760115067822
# Simple call dropped at 48.5984391370551
# Simple call dropped at 48.62893897571254
# Simple call dropped at 48.80698641434246
# Complex call dropped at 48.81390453371877
# Complex call dropped at 48.96504425455963
# Simple call dropped at 48.977028650291935
# Simple call dropped at 51.803337625031574
# Complex call dropped at 51.842018795868604
# Complex call dropped at 52.1321284049288
# Simple call dropped at 52.35458673843776
# Simple call dropped at 52.36957948474377
# Simple call dropped at 52.4020447368653
# Complex call dropped at 52.43519312061913
# Simple call dropped at 52.505009237910556
# Simple call dropped at 52.90963113950295
# Simple call dropped at 53.64846237392996
# Simple call dropped at 53.67788035301399
# Simple call dropped at 53.68419473760898
# Simple call dropped at 53.68934331176257
# Simple call dropped at 53.73760283499954
# Complex call dropped at 53.85735318318105
# Simple call dropped at 53.92960988809355
# Simple call dropped at 54.1055952240309
# Simple call dropped at 54.144169664418065
# Simple call dropped at 54.19652339682077
# Complex call dropped at 54.199227856874145
# Simple call dropped at 54.22246116925006
# Simple call dropped at 54.230946516554035
# Complex call dropped at 54.256210075247694
# Simple call dropped at 54.259512262561145
# Simple call dropped at 54.353636321393914
# Complex call dropped at 54.4324919391569
# Complex call dropped at 54.57042879265496
# Simple call dropped at 54.60304346245915
# Simple call dropped at 54.60499755343871
# Complex call dropped at 54.64421892704877
# Complex call dropped at 55.19725071110856
# Simple call dropped at 56.47626819800387
# Simple call dropped at 57.24549623818237
# Simple call dropped at 57.53780399234785
# Simple call dropped at 57.63553716150537
# Simple call dropped at 57.67955988013712
# Simple call dropped at 61.74456369638767
# Simple call dropped at 61.76173365468408
# Complex call dropped at 61.855044857561126
# Simple call dropped at 61.872912774046284
# Simple call dropped at 61.95889572051025
# Simple call dropped at 62.12047571118419
# Simple call dropped at 62.30992917284317
# Complex call dropped at 62.312743902519124
# Simple call dropped at 62.317490191301296
# Simple call dropped at 62.33451508603454
# Simple call dropped at 62.34714297155576
# Simple call dropped at 62.37972406580908
# Simple call dropped at 62.40348086316341
# Simple call dropped at 62.42866143328534
# Simple call dropped at 63.747107381565115
# Simple call dropped at 63.81206328334821
# Simple call dropped at 63.8637799614048
# Simple call dropped at 64.46980897480448
# Simple call dropped at 64.95891583041066
# Simple call dropped at 65.2227966333246
# Simple call dropped at 65.22308657839439
# Simple call dropped at 65.22500305840852
# Simple call dropped at 65.25453131562615
# Simple call dropped at 65.34780839018163
# Complex call dropped at 65.4489462572414
# Simple call dropped at 65.4922787228468
# Complex call dropped at 65.50582031334115
# Simple call dropped at 65.52768640621827
# Simple call dropped at 65.99853043324717
# Simple call dropped at 66.0189443049958
# Complex call dropped at 66.02293586017159
# Complex call dropped at 66.03455578008827
# Simple call dropped at 66.21704183964853
# Simple call dropped at 66.29296670806309
# Simple call dropped at 66.38599709453135
# Complex call dropped at 67.39688728471164
# Complex call dropped at 67.42568278051068
# Simple call dropped at 67.44997142270182
# Simple call dropped at 67.46891502188292
# Complex call dropped at 67.4813238089511
# Simple call dropped at 67.55561954582471
# Simple call dropped at 67.712135340927
# Simple call dropped at 67.7202205109588
# Simple call dropped at 67.82767677623889
# Simple call dropped at 67.84528642613972
# Simple call dropped at 67.87133688850841
# Simple call dropped at 67.96465789061284
# Complex call dropped at 67.99211369648411
# Simple call dropped at 68.04162644539134
# Simple call dropped at 69.60923619281468
# Simple call dropped at 69.89698833506829
# Simple call dropped at 69.93680311894269
# Simple call dropped at 70.11092269302281
# Simple call dropped at 70.25456284958616
# Complex call dropped at 70.5339438321102
# Complex call dropped at 70.54604931837902
# Complex call dropped at 70.55293112146134
# Simple call dropped at 70.72972780081835
# Complex call dropped at 70.92799940612926
# Simple call dropped at 70.9432675123289
# Complex call dropped at 71.02142518085267
# Simple call dropped at 71.02342613263498
# Simple call dropped at 71.10329831135796
# Simple call dropped at 71.15886011795932
# Simple call dropped at 71.25247618663671
# Simple call dropped at 71.55478142028537
# Simple call dropped at 72.02028446139641
# Simple call dropped at 72.06002191506634
# Simple call dropped at 72.94332037058953
# Complex call dropped at 73.65476270578884
# Simple call dropped at 73.6693045476398
# Complex call dropped at 73.9478351142295
# Simple call dropped at 73.95657980544117
# Simple call dropped at 74.39447096045288
# Simple call dropped at 74.40842905546066
# Simple call dropped at 74.69698223374238
# Simple call dropped at 74.92680087384622
# Complex call dropped at 74.92870887019686
# Simple call dropped at 75.3580851885812
# Complex call dropped at 75.36234866339191
# Simple call dropped at 75.39981352688368
# Simple call dropped at 75.40924167315251
# Simple call dropped at 75.47317032256574
# Simple call dropped at 75.5538444818795
# Complex call dropped at 75.5585324816114
# Complex call dropped at 75.63849124058518
# Complex call dropped at 75.72000557277596
# Simple call dropped at 75.90413518789676
# Simple call dropped at 75.93556392628908
# Simple call dropped at 76.38431435811232
# Simple call dropped at 76.4534618768025
# Complex call dropped at 77.50741567051159
# Simple call dropped at 77.55851821336731
# Simple call dropped at 77.56591916917522
# Complex call dropped at 77.7107375590588
# Simple call dropped at 77.7245572772864
# Simple call dropped at 77.72833292420118
# Simple call dropped at 78.33280051578939
# Complex call dropped at 78.35550511349365
# Complex call dropped at 78.38018044469885
# Complex call dropped at 84.09829320895
# Simple call dropped at 84.18068836123493
# Simple call dropped at 84.18614044282295
# Complex call dropped at 84.18699600213482
# Complex call dropped at 84.23613261966999
# Simple call dropped at 84.24984718680071
# Simple call dropped at 84.2696862461741
# Simple call dropped at 84.330088609086
# Complex call dropped at 84.34843121465963
# Simple call dropped at 84.44120615978876
# Simple call dropped at 84.44994683631151
# Complex call dropped at 84.5419708587126
# Complex call dropped at 85.09432438508243
# Simple call dropped at 85.34285566630817
# Complex call dropped at 85.35229197495828
# Simple call dropped at 85.38310563241039
# Simple call dropped at 85.39211071697544
# Simple call dropped at 85.42343844444822
# Complex call dropped at 85.67413108868884
# Simple call dropped at 85.71740055510799
# Simple call dropped at 85.7181097931718
# Simple call dropped at 85.80559978300896
# Simple call dropped at 85.85393278701908
# Simple call dropped at 85.8676108588664
# Simple call dropped at 85.91182211518428
# Simple call dropped at 86.00850269929856
# Complex call dropped at 86.02316733140995
# Simple call dropped at 86.24417082092776
# Simple call dropped at 86.25672294212387
# Simple call dropped at 86.28374805239952
# Simple call dropped at 86.29108225866557
# Complex call dropped at 86.32052790621483
# Simple call dropped at 86.35825595847376
# Simple call dropped at 86.4362106221891
# Complex call dropped at 86.50378998624127
# Simple call dropped at 86.5619985611847
# Simple call dropped at 86.71892899207984
# Complex call dropped at 86.73833396379973
# Simple call dropped at 86.80843987021159
# Complex call dropped at 86.8101407467895
# Simple call dropped at 86.89840799166963
# Simple call dropped at 86.90308420078502
# Complex call dropped at 86.95261594826653
# Simple call dropped at 87.09324466591218
# Simple call dropped at 87.27046721760631
# Complex call dropped at 87.59968862775352
# Simple call dropped at 88.5262615807161
# Simple call dropped at 88.63870962289845
# Complex call dropped at 88.74532158902518
# Simple call dropped at 88.76442921793763
# Complex call dropped at 88.81932865250548
# Complex call dropped at 89.18838968773088
# Simple call dropped at 89.2456939526517
# Simple call dropped at 89.56961213508036
# Simple call dropped at 89.64070464320884
# Complex call dropped at 89.67528897549911
# Complex call dropped at 89.68429637923221
# Simple call dropped at 89.69995085695014
# Simple call dropped at 89.72332115700482
# Simple call dropped at 90.09724574238047
# Complex call dropped at 90.18940564483275
# Complex call dropped at 90.29222307419923
# Simple call dropped at 90.40341370931841
# Complex call dropped at 94.51992331204485
# Simple call dropped at 94.85459348927193
# Complex call dropped at 94.95188453373035
# Simple call dropped at 94.96800277237298
# Simple call dropped at 94.98452164067793
# Simple call dropped at 95.01652274112247
# Simple call dropped at 95.03712323932929
# Complex call dropped at 95.0502137713855
# Simple call dropped at 95.22554867419777
# Simple call dropped at 95.23058016040122
# Complex call dropped at 95.35171487780579
# Complex call dropped at 95.50247796255665
# Simple call dropped at 96.69928267546273
# Complex call dropped at 97.01960412318884
# Complex call dropped at 97.03852283342484
# Simple call dropped at 97.0576145406428
# Simple call dropped at 97.0781925011547
# Complex call dropped at 97.09147834134144
# Complex call dropped at 97.09161508735623
# Simple call dropped at 97.14048372095706
# Simple call dropped at 97.15923169661362
# Simple call dropped at 97.17088377343198
# Simple call dropped at 98.28544512143978
# Complex call dropped at 102.00956883944
# Simple call dropped at 102.05002976430106
# Complex call dropped at 102.06086813504312
# Simple call dropped at 102.41685864855602
# Simple call dropped at 102.99826175590496
# Simple call dropped at 103.22949935117491
# Simple call dropped at 106.3460901080834
# Simple call dropped at 108.62400353387449
# Simple call dropped at 109.118747797776
# Complex call dropped at 111.0875843732485
# Simple call dropped at 111.0975308402075
# Simple call dropped at 111.20107010411058
# Complex call dropped at 111.25307151893426
# Simple call dropped at 111.3095147233548
# Simple call dropped at 111.34386811816665
# Complex call dropped at 111.43452281105684
# Simple call dropped at 112.9615655031991
# Simple call dropped at 112.99073681634403
# Simple call dropped at 112.99408707730252
# Simple call dropped at 113.05124399855727
# Simple call dropped at 113.0706446300822
# Simple call dropped at 116.15588308734237
# Simple call dropped at 116.18315588013257
# Simple call dropped at 116.20415065470488
# Complex call dropped at 116.24341156827923
# Simple call dropped at 116.2900597154959
# Simple call dropped at 116.31238300259125
# Complex call dropped at 116.34667201806069
# Simple call dropped at 116.36359224151494
# Simple call dropped at 116.46250110096551
# Simple call dropped at 116.47303151461931
# Simple call dropped at 116.53035715021579
# Simple call dropped at 116.95818124206278
# Simple call dropped at 117.11645498686781
# Simple call dropped at 117.12654371124758
# Complex call dropped at 117.13888993007298
# Simple call dropped at 117.24523428002831
# Complex call dropped at 117.54328549063588
# Simple call dropped at 117.55472371048904
# Simple call dropped at 117.66126949666041
# Simple call dropped at 117.67069662933655
# Complex call dropped at 118.22569786992159
# Complex call dropped at 120.68925467093472
# Simple call dropped at 120.71517445323546
# Complex call dropped at 120.75680163108326
# Complex call dropped at 120.82675300716171
# Simple call dropped at 120.83696895817994
# Simple call dropped at 120.83970560429826
# Complex call dropped at 121.16116350203816
# Simple call dropped at 121.59095470055385
# Complex call dropped at 121.61736415631542
# Simple call dropped at 121.67170997273257
# Complex call dropped at 122.19932670550563
# Simple call dropped at 122.75975888809957
# Complex call dropped at 122.76005620466407
# Simple call dropped at 122.765643206996
# Simple call dropped at 123.08505706829075
# Simple call dropped at 123.13422291279664
# Simple call dropped at 124.28498797729902
# Simple call dropped at 124.30025428644991
# Simple call dropped at 126.5424431157137
# Simple call dropped at 126.55340282094211
# Simple call dropped at 126.55382303188314
# Complex call dropped at 126.75032801090518
# Simple call dropped at 126.81907367583545
# Simple call dropped at 128.22079816895106
# Simple call dropped at 128.40595442436486
# Complex call dropped at 128.43351074931027
# Complex call dropped at 128.44941949776648
# Complex call dropped at 128.46509830190607
# Complex call dropped at 128.4751977332697
# Simple call dropped at 129.02246577535263
# Simple call dropped at 129.1401059574806
# Simple call dropped at 129.38266744691367
# Simple call dropped at 129.44281977443586
# Simple call dropped at 129.8522635936016
# Simple call dropped at 129.9079912576951
# Simple call dropped at 129.9170475556492
# Simple call dropped at 129.93635148885335
# Complex call dropped at 129.98306059482354
# Complex call dropped at 130.19397254510983
# Simple call dropped at 130.26894869344758
# Complex call dropped at 130.34133924316222
# Simple call dropped at 130.41643897994274
# Simple call dropped at 130.4419053414584
# Simple call dropped at 130.5074078784837
# Simple call dropped at 130.5233227702925
# Simple call dropped at 130.61168764884255
# Simple call dropped at 130.6495707951971
# Complex call dropped at 130.70154643525012
# Simple call dropped at 130.77719852741703
# Simple call dropped at 131.10333484253255
# Complex call dropped at 131.10844689299236
# Complex call dropped at 131.15597580595363
# Simple call dropped at 131.18928122018076
# Complex call dropped at 131.19735743720338
# Simple call dropped at 131.35473624578796
# Simple call dropped at 131.40947352599727
# Complex call dropped at 131.45003315620215
# Simple call dropped at 131.46377765336146
# Simple call dropped at 131.47843083098863
# Complex call dropped at 131.49735591781157
# Complex call dropped at 131.501896274754
# Complex call dropped at 131.51071681782304
# Simple call dropped at 132.13522399750426
# Simple call dropped at 132.46578060225409
# Complex call dropped at 133.3050192166402
# Complex call dropped at 133.32558460850427
# Simple call dropped at 133.37568624524442
# Simple call dropped at 133.74150306320436
# Complex call dropped at 133.82599297374782
# Simple call dropped at 133.83850345753623
# Simple call dropped at 135.18435420487452
# Simple call dropped at 135.20312752863776
# Simple call dropped at 135.29226814077464
# Simple call dropped at 135.2951170681393
# Complex call dropped at 135.3074478844611
# Simple call dropped at 135.37137363054376
# Simple call dropped at 135.39333506527464
# Simple call dropped at 135.40881062779775
# Simple call dropped at 135.41187124467336
# Simple call dropped at 135.4346595112677
# Simple call dropped at 135.43468345402815
# Simple call dropped at 135.44895979179054
# Complex call dropped at 135.4525049619824
# Complex call dropped at 136.97018005905045
# Simple call dropped at 137.90882041842983
# Complex call dropped at 137.94491437128798
# Complex call dropped at 138.00760347012687
# Simple call dropped at 138.09609576526938
# Simple call dropped at 138.19186177152827
# Simple call dropped at 139.55052848404196
# Simple call dropped at 139.65707914316636
# Complex call dropped at 139.6581463569672
# Complex call dropped at 139.6965723442894
# Simple call dropped at 139.7536992570997
# Simple call dropped at 139.87425792227214
# Simple call dropped at 140.13945355482468
# Simple call dropped at 140.41287847124374
# Simple call dropped at 140.42459283058622
# Complex call dropped at 140.4678277200538
# Simple call dropped at 140.83751266602366
# Complex call dropped at 140.84630339511236
# Simple call dropped at 140.94376007083335
# Simple call dropped at 140.97348705223158
# Simple call dropped at 141.0898147431535
# Complex call dropped at 141.27355140793196
# Simple call dropped at 141.33736753057255
# Simple call dropped at 141.34813758048392
# Simple call dropped at 142.026547132606
# Simple call dropped at 142.05830397972719
# Simple call dropped at 142.08700418739824
# Simple call dropped at 142.11294204132798
# Simple call dropped at 142.16199238271756
# Complex call dropped at 142.17238513811319
# Simple call dropped at 142.34445607384825
# Simple call dropped at 142.3464037492207
# Complex call dropped at 142.36951738909917
# Simple call dropped at 142.45483015407368
# Simple call dropped at 142.69211724295243
# Simple call dropped at 142.7415156287111
# Simple call dropped at 142.76688433424798
# Simple call dropped at 142.78094628367342
# Simple call dropped at 142.8695901154317
# Complex call dropped at 143.70827405013748
# Simple call dropped at 143.85427505616536
# Simple call dropped at 143.88442440448117
# Simple call dropped at 143.88443210036942
# Complex call dropped at 143.89901784463572
# Simple call dropped at 144.3985946744514
# Simple call dropped at 144.68118949007055
# Simple call dropped at 144.8387696139767
# Complex call dropped at 144.85002108317002
# Complex call dropped at 144.8902992512004
# Complex call dropped at 144.95868334526787
# Simple call dropped at 144.99882020987906
# Simple call dropped at 145.09792089335795
# Simple call dropped at 145.10216306643872
# Complex call dropped at 145.16129472974902
# Simple call dropped at 145.1659676479993
# Simple call dropped at 145.17495846551057
# Simple call dropped at 145.2010925317209
# Complex call dropped at 145.20243838078062
# Complex call dropped at 145.77566457686592
# Complex call dropped at 145.7904767211582
# Simple call dropped at 145.81369000850387
# Simple call dropped at 145.83147594476048
# Simple call dropped at 145.9849966605797
# Simple call dropped at 145.99583540229972
# Complex call dropped at 146.26985322445853
# Complex call dropped at 146.2766701501942
# Simple call dropped at 146.27789570202674
# Complex call dropped at 146.40021674140957
# Simple call dropped at 146.40073034100007
# Complex call dropped at 146.5474857738675
# Simple call dropped at 147.05996335123427
# Simple call dropped at 147.07522621216296
# Simple call dropped at 147.10215138534977
# Simple call dropped at 147.11277099033893
# Complex call dropped at 147.14745070395432
# Complex call dropped at 147.14924469715754
# Complex call dropped at 147.15782481302662
# Simple call dropped at 147.24248589038098
# Simple call dropped at 147.3349134533889
# Simple call dropped at 147.3427250623302
# Simple call dropped at 147.35702649573193
# Simple call dropped at 147.36501416524155
# Complex call dropped at 147.46383488789505
# Simple call dropped at 148.69604230483924
# Simple call dropped at 148.88075555966324
# Complex call dropped at 148.96718576139878
# Simple call dropped at 148.98713524855648
# Simple call dropped at 149.19788590228407
# Complex call dropped at 149.38677705561435
# Simple call dropped at 149.4129705673251
# Simple call dropped at 149.88394154042737
# Simple call dropped at 150.44139808504133
# Complex call dropped at 150.46646206492096
# Simple call dropped at 150.50461166804686
# Complex call dropped at 150.5084730842092
# Simple call dropped at 150.56685776376648
# Complex call dropped at 150.60510147280536
# Simple call dropped at 150.6821141782976
# Simple call dropped at 150.6914063641904
# Complex call dropped at 150.71239328031157
# Complex call dropped at 150.8010152631945
# Simple call dropped at 151.92208543127
# Complex call dropped at 151.9758112443347
# Simple call dropped at 152.09081644899115
# Complex call dropped at 152.82382441754152
# Simple call dropped at 152.860066997573
# Simple call dropped at 152.88217206829304
# Simple call dropped at 153.74256209647515
# Simple call dropped at 153.78273335454458
# Complex call dropped at 154.11846284712513
# Simple call dropped at 154.1229676014852
# Simple call dropped at 154.1271816345904
# Simple call dropped at 154.2393459819671
# Simple call dropped at 154.2514190133932
# Complex call dropped at 154.28792802818617
# Simple call dropped at 154.33789082659573
# Simple call dropped at 154.41764953417876
# Complex call dropped at 154.42175990844424
# Complex call dropped at 154.5564361565873
# Complex call dropped at 154.57520922399368
# Simple call dropped at 154.8725405365586
# Simple call dropped at 155.70005142674654
# Simple call dropped at 155.70988232629972
# Complex call dropped at 155.7222469802691
# Complex call dropped at 155.7268491493858
# Simple call dropped at 155.75971140576948
# Complex call dropped at 155.77374302406403
# Simple call dropped at 155.82406158923794
# Simple call dropped at 155.87904186714383
# Complex call dropped at 155.87918298284515
# Complex call dropped at 155.9133730968042
# Simple call dropped at 155.98812939514298
# Simple call dropped at 156.0788995084178
# Simple call dropped at 156.08260414837696
# Complex call dropped at 156.08830927915488
# Simple call dropped at 156.09816371248442
# Complex call dropped at 156.16603732592029
# Simple call dropped at 156.49640697779083
# Simple call dropped at 156.53633759558215
# Simple call dropped at 159.26016514907514
# Simple call dropped at 159.47395421331856
# Simple call dropped at 159.59979428531477
# Simple call dropped at 159.60920368336423
# Simple call dropped at 159.62622503061078
# Simple call dropped at 159.77187409080966
# Complex call dropped at 159.77693880019172
# Simple call dropped at 160.07542677408227
# Complex call dropped at 160.10410333937944
# Complex call dropped at 160.1071289624856
# Simple call dropped at 160.75648286258703
# Complex call dropped at 164.04798474937445
# Simple call dropped at 164.0527831627643
# Complex call dropped at 164.07688491148144
# Complex call dropped at 164.14104129859504
# Simple call dropped at 164.1516328742242
# Simple call dropped at 164.2136075350214
# Simple call dropped at 164.3127881075885
# Complex call dropped at 164.31394559879416
# Simple call dropped at 164.51905308104855
# Simple call dropped at 165.4133855372943
# Simple call dropped at 165.41540880108826
# Simple call dropped at 165.49724702232066
# Simple call dropped at 165.50770360676066

# %%
# Simulate for a month (720 hours)
results_month = run_simulation(opt_simple_policy, opt_complex_policy, sim_time=720)
# Plot the results for the month
plot_queue_length_over_time(results_month)
plot_waiting_times_by_queue(results_month)
# Out:
# Simple call dropped at 58.92873572328166
# Simple call dropped at 61.10431993651821
# Complex call dropped at 62.03679002176498
# Simple call dropped at 70.08678192751795
# Complex call dropped at 70.2421254556151
# Simple call dropped at 71.71912536678859
# Simple call dropped at 71.92744518069263
# Simple call dropped at 71.96737994582135
# Simple call dropped at 71.97983619830919
# Simple call dropped at 72.00969389369412
# Complex call dropped at 74.68512068352389
# Simple call dropped at 74.70801140008734
# Simple call dropped at 74.73296153672273
# Simple call dropped at 75.01760554732678
# Simple call dropped at 75.5335142498858
# Simple call dropped at 75.7262283112565
# Simple call dropped at 75.74077122468715
# Simple call dropped at 75.8091576681192
# Simple call dropped at 76.67867179898712
# Complex call dropped at 76.70213925445444
# Complex call dropped at 76.89427279082899
# Simple call dropped at 77.03223470368492
# Simple call dropped at 77.25939931982278
# Complex call dropped at 79.16577199910986
# Simple call dropped at 79.25134841287945
# Simple call dropped at 79.27573549847052
# Simple call dropped at 79.40214977317576
# Complex call dropped at 79.43443605875125
# Simple call dropped at 80.10517355405518
# Simple call dropped at 80.20873153605615
# Complex call dropped at 80.41545286046393
# Simple call dropped at 81.903612824993
# Complex call dropped at 81.95910069031086
# Simple call dropped at 82.02066534685707
# Simple call dropped at 82.06992039752434
# Simple call dropped at 82.10124812499713
# Simple call dropped at 82.39591947372071
# Complex call dropped at 82.48092381282363
# Simple call dropped at 82.48340946355786
# Simple call dropped at 82.5902169157039
# Complex call dropped at 82.59692302244791
# Complex call dropped at 82.6297503948815
# Simple call dropped at 82.67263996609465
# Simple call dropped at 83.33535081974243
# Simple call dropped at 83.5255112848696
# Simple call dropped at 83.53547973026467
# Complex call dropped at 83.54363774744054
# Simple call dropped at 83.91009175970841
# Complex call dropped at 84.1499472213368
# Complex call dropped at 84.17205976404503
# Complex call dropped at 84.18453462703495
# Simple call dropped at 84.51900282302742
# Simple call dropped at 84.65655056283131
# Complex call dropped at 84.7519720016572
# Simple call dropped at 84.84531266066452
# Simple call dropped at 84.85282579030054
# Simple call dropped at 84.90032712053508
# Simple call dropped at 84.95065932824673
# Complex call dropped at 85.01380783649797
# Simple call dropped at 85.02887759305138
# Complex call dropped at 85.11325502498639
# Simple call dropped at 85.1416782971951
# Simple call dropped at 85.24242696750491
# Simple call dropped at 85.25733750781365
# Complex call dropped at 85.67090610586477
# Simple call dropped at 85.73633060293048
# Simple call dropped at 86.05177923061008
# Complex call dropped at 86.05188985939283
# Complex call dropped at 86.06089726312592
# Simple call dropped at 86.53157382901955
# Simple call dropped at 86.56393349732093
# Complex call dropped at 86.56707584597909
# Simple call dropped at 86.61554861005965
# Simple call dropped at 89.76247779370637
# Simple call dropped at 89.76348020888585
# Complex call dropped at 89.90948269628704
# Simple call dropped at 89.91132599484553
# Simple call dropped at 89.92299970464323
# Simple call dropped at 90.55874566711674
# Simple call dropped at 90.56123946972552
# Simple call dropped at 115.69728537757436
# Simple call dropped at 115.92615494354453
# Complex call dropped at 115.9297982911373
# Complex call dropped at 115.93636624182129
# Complex call dropped at 117.51394803239752
# Simple call dropped at 117.53074180099897
# Complex call dropped at 117.54732510647504
# Simple call dropped at 118.94621826023211
# Simple call dropped at 118.97392167399188
# Simple call dropped at 119.21499142448735
# Simple call dropped at 119.35029323417223
# Complex call dropped at 119.43469063627411
# Simple call dropped at 119.45955332585487
# Simple call dropped at 119.47481963500576
# Simple call dropped at 119.73564153923576
# Simple call dropped at 119.79998619848175
# Simple call dropped at 119.80059933073169
# Simple call dropped at 119.80624212236744
# Simple call dropped at 120.59392906151945
# Simple call dropped at 120.61886903463815
# Simple call dropped at 120.70707873470901
# Simple call dropped at 120.70849833868368
# Complex call dropped at 120.71534320382672
# Complex call dropped at 120.8684155525066
# Simple call dropped at 120.88199489877573
# Simple call dropped at 120.95540680922323
# Simple call dropped at 121.19416298313779
# Simple call dropped at 121.23605581998443
# Simple call dropped at 121.32613406016476
# Simple call dropped at 121.33835273622152
# Simple call dropped at 121.3796798031809
# Complex call dropped at 121.43621729335125
# Simple call dropped at 121.71591084643494
# Simple call dropped at 121.75482892291434
# Complex call dropped at 121.93830513099364
# Simple call dropped at 122.00358651975992
# Simple call dropped at 122.09806617179783
# Complex call dropped at 122.20417135037484
# Simple call dropped at 122.21302482313764
# Complex call dropped at 122.31059975827615
# Simple call dropped at 122.31417107853733
# Simple call dropped at 122.46419490499598
# Simple call dropped at 122.74108732572498
# Simple call dropped at 122.76970482420369
# Simple call dropped at 122.77551640430768
# Complex call dropped at 122.78296410492345
# Simple call dropped at 122.7841301689638
# Simple call dropped at 122.83978439167741
# Simple call dropped at 122.87326342676728
# Simple call dropped at 122.88469781120587
# Complex call dropped at 123.73370698964888
# Simple call dropped at 123.79929789266606
# Simple call dropped at 123.83138368982614
# Simple call dropped at 123.8379165248843
# Simple call dropped at 123.8394836936208
# Complex call dropped at 123.88841279486287
# Complex call dropped at 123.8947510212589
# Simple call dropped at 123.89845101499925
# Simple call dropped at 124.13904394538295
# Simple call dropped at 125.36554951492954
# Simple call dropped at 125.83951609739877
# Simple call dropped at 125.90501863442405
# Simple call dropped at 125.92093352623286
# Simple call dropped at 126.06988514929138
# Simple call dropped at 126.10922947780533
# Simple call dropped at 126.6018736036556
# Simple call dropped at 126.74429301070631
# Simple call dropped at 126.74796823698509
# Complex call dropped at 127.11897763509107
# Simple call dropped at 127.1622985303244
# Simple call dropped at 128.2948722130896
# Complex call dropped at 128.31456794449906
# Simple call dropped at 128.3165970286817
# Simple call dropped at 129.10369818020473
# Complex call dropped at 129.14082101371736
# Complex call dropped at 130.96029225087818
# Complex call dropped at 131.02502536711881
# Complex call dropped at 131.21149079724398
# Complex call dropped at 131.25475546788135
# Simple call dropped at 131.30332098264284
# Complex call dropped at 131.3152760365091
# Complex call dropped at 131.33778998141915
# Simple call dropped at 131.34688664357904
# Complex call dropped at 131.35281789126495
# Simple call dropped at 131.37592804332903
# Simple call dropped at 131.51128291068758
# Simple call dropped at 131.91272070498684
# Complex call dropped at 131.94036893202806
# Simple call dropped at 131.9840054086722
# Simple call dropped at 133.94567288391224
# Simple call dropped at 134.0696846347731
# Simple call dropped at 134.1245466396961
# Complex call dropped at 134.39740943148195
# Complex call dropped at 135.6818900077024
# Simple call dropped at 135.74688320263527
# Simple call dropped at 137.6875543493056
# Complex call dropped at 137.68813010225125
# Simple call dropped at 137.69304751862134
# Complex call dropped at 138.11001291733973
# Simple call dropped at 138.13307983219872
# Complex call dropped at 138.13815913515313
# Complex call dropped at 138.14395661462012
# Simple call dropped at 138.28502651789898
# Complex call dropped at 138.49112903545202
# Simple call dropped at 138.52463336851056
# Simple call dropped at 139.00336890057628
# Simple call dropped at 139.17927502997685
# Simple call dropped at 139.47894337580283
# Simple call dropped at 139.51855929343654
# Simple call dropped at 139.566809383137
# Simple call dropped at 139.78349674502488
# Simple call dropped at 139.8966963090352
# Simple call dropped at 140.14375879467775
# Complex call dropped at 140.16416529535667
# Simple call dropped at 140.16989286088807
# Simple call dropped at 142.10147806620634
# Simple call dropped at 142.3172208850213
# Simple call dropped at 143.97736658466516
# Complex call dropped at 144.13985193294846
# Simple call dropped at 145.1176824851189
# Complex call dropped at 145.1236129389953
# Simple call dropped at 145.2025022468932
# Complex call dropped at 145.21223492187823
# Simple call dropped at 145.25365388593033
# Simple call dropped at 146.40307355345928
# Simple call dropped at 146.5644070844705
# Simple call dropped at 146.566235443587
# Simple call dropped at 146.7100382995281
# Complex call dropped at 147.35206418867716
# Simple call dropped at 147.4780790744098
# Complex call dropped at 147.58603973029668
# Simple call dropped at 147.6887514319728
# Complex call dropped at 148.07708643489806
# Simple call dropped at 148.11791211590608
# Simple call dropped at 148.18693017057296
# Complex call dropped at 148.3815268016417
# Complex call dropped at 148.39164048109427
# Simple call dropped at 148.5027557680334
# Simple call dropped at 148.5148287994595
# Complex call dropped at 148.52147489970318
# Simple call dropped at 148.60130061266204
# Simple call dropped at 148.68105932024508
# Simple call dropped at 148.6872543184029
# Simple call dropped at 149.44948493636116
# Simple call dropped at 149.4541584027111
# Complex call dropped at 149.7832183428271
# Simple call dropped at 149.84501796066655
# Simple call dropped at 149.85484886021973
# Simple call dropped at 150.0489495032573
# Simple call dropped at 150.06164874383364
# Simple call dropped at 150.25610951056683
# Complex call dropped at 150.28172865036115
# Simple call dropped at 153.65565755649035
# Simple call dropped at 153.6650669545398
# Simple call dropped at 153.68208830178637
# Simple call dropped at 153.82773736198524
# Simple call dropped at 154.10491605572014
# Complex call dropped at 154.14422543489812
# Simple call dropped at 154.68999037279065
# Complex call dropped at 157.53082931351912
# Complex call dropped at 157.5383117621824
# Simple call dropped at 164.47398967088998
# Simple call dropped at 164.48534559960618
# Simple call dropped at 164.49439758677178
# Simple call dropped at 171.9742079471638
# Simple call dropped at 172.01555707455427
# Complex call dropped at 172.15042606333301
# Simple call dropped at 172.24963280944854
# Simple call dropped at 172.26770120016482
# Simple call dropped at 172.3185297880848
# Simple call dropped at 172.38463114541872
# Simple call dropped at 172.38563393911275
# Simple call dropped at 172.39420117620742
# Simple call dropped at 172.40334379241992
# Simple call dropped at 172.47242731627054
# Simple call dropped at 172.4804645025794
# Simple call dropped at 173.44734164427766
# Simple call dropped at 173.49374502681195
# Simple call dropped at 173.68850239982163
# Simple call dropped at 173.998820691451
# Simple call dropped at 175.13120320632382
# Simple call dropped at 175.13147927646548
# Complex call dropped at 178.81463853548263
# Complex call dropped at 178.85432883712537
# Simple call dropped at 179.11069199148395
# Complex call dropped at 179.2427708471508
# Complex call dropped at 179.30748150006286
# Simple call dropped at 179.31974708380827
# Simple call dropped at 179.46863228214264
# Simple call dropped at 180.74760146042902
# Simple call dropped at 180.75272687387178
# Simple call dropped at 180.764957133685
# Simple call dropped at 181.16604492793766
# Simple call dropped at 181.2662416568318
# Complex call dropped at 181.33406136880512
# Complex call dropped at 181.72300680781387
# Simple call dropped at 181.78461626984512
# Complex call dropped at 181.78847744214278
# Simple call dropped at 181.89373285985263
# Simple call dropped at 181.91733543455337
# Complex call dropped at 182.05497422256352
# Simple call dropped at 182.1357048392556
# Simple call dropped at 182.14914713491925
# Simple call dropped at 182.22019828461546
# Simple call dropped at 182.2206224942787
# Simple call dropped at 182.99129764909387
# Simple call dropped at 183.04185410014324
# Simple call dropped at 183.24686985568738
# Simple call dropped at 183.29888428171938
# Simple call dropped at 183.30499446082368
# Simple call dropped at 183.49157736907043
# Simple call dropped at 184.18965824356857
# Complex call dropped at 184.28572886860465
# Simple call dropped at 184.31622643793932
# Simple call dropped at 184.33584823603445
# Simple call dropped at 184.44972800966582
# Simple call dropped at 184.4969408822049
# Simple call dropped at 184.59195280666037
# Simple call dropped at 184.71661965662116
# Simple call dropped at 184.72752940859172
# Simple call dropped at 184.83063541565753
# Complex call dropped at 185.132666296927
# Simple call dropped at 187.16778375789696
# Simple call dropped at 187.20289720027668
# Complex call dropped at 187.2301135805541
# Simple call dropped at 187.24178662355206
# Simple call dropped at 187.25657417097094
# Simple call dropped at 187.2864829769992
# Simple call dropped at 188.10549206042987
# Simple call dropped at 188.13618273690173
# Simple call dropped at 188.1789782249674
# Simple call dropped at 188.33215133032564
# Simple call dropped at 188.33686849248693
# Complex call dropped at 188.35062146442658
# Simple call dropped at 188.65856759025235
# Complex call dropped at 188.8663637523032
# Complex call dropped at 188.95865340794847
# Complex call dropped at 189.05196130353264
# Complex call dropped at 189.07029636113828
# Simple call dropped at 189.21554067875692
# Simple call dropped at 189.44610543488952
# Simple call dropped at 189.63506345459746
# Simple call dropped at 189.64759014846152
# Complex call dropped at 189.8006262209059
# Simple call dropped at 190.6237734449634
# Simple call dropped at 190.62604067709123
# Simple call dropped at 190.62624481650442
# Simple call dropped at 190.6516389207984
# Simple call dropped at 191.01339373394674
# Complex call dropped at 191.0156894063834
# Simple call dropped at 192.97252535370333
# Simple call dropped at 192.97914839987033
# Simple call dropped at 193.12151513717976
# Complex call dropped at 193.17833184337766
# Simple call dropped at 193.50749307769686
# Simple call dropped at 193.5143152786889
# Complex call dropped at 193.6507963004531
# Simple call dropped at 193.7352310349759
# Simple call dropped at 193.74578181569532
# Simple call dropped at 193.77009071478423
# Simple call dropped at 193.77580269115742
# Simple call dropped at 194.0860941985657
# Complex call dropped at 194.0933458588305
# Complex call dropped at 194.86940624325834
# Complex call dropped at 194.9093034985596
# Complex call dropped at 194.99694941174116
# Simple call dropped at 195.030426983953
# Simple call dropped at 195.05052257965727
# Simple call dropped at 195.07203870055338
# Simple call dropped at 195.08201670931612
# Complex call dropped at 195.09243243520262
# Simple call dropped at 198.1222400954486
# Simple call dropped at 198.227057331375
# Complex call dropped at 198.276256279948
# Simple call dropped at 198.28275455003612
# Complex call dropped at 198.29942421339078
# Simple call dropped at 198.37642169426218
# Complex call dropped at 198.51523237999342
# Simple call dropped at 198.52662711471302
# Simple call dropped at 198.6423931877451
# Simple call dropped at 199.12857734427539
# Complex call dropped at 199.7606636126954
# Simple call dropped at 199.76285928516472
# Simple call dropped at 199.77164457674633
# Simple call dropped at 199.8653339602847
# Simple call dropped at 199.89945263765347
# Simple call dropped at 200.02987164027897
# Complex call dropped at 200.09105605909605
# Simple call dropped at 200.26650992632918
# Complex call dropped at 200.47098932160736
# Complex call dropped at 201.44682499456263
# Complex call dropped at 202.00026699911908
# Complex call dropped at 202.05952994714102
# Complex call dropped at 202.08363799352858
# Simple call dropped at 204.85709206571926
# Simple call dropped at 204.92414107839744
# Complex call dropped at 204.95883311214538
# Simple call dropped at 204.99253793462572
# Simple call dropped at 205.00338542856335
# Simple call dropped at 205.21245586748657
# Complex call dropped at 205.29336222821192
# Complex call dropped at 205.39319947595226
# Simple call dropped at 205.4129229522039
# Simple call dropped at 205.43751359218265
# Simple call dropped at 205.44539574240835
# Simple call dropped at 206.39744670068745
# Complex call dropped at 206.53659964237985
# Simple call dropped at 206.57191599763976
# Complex call dropped at 206.88537400904454
# Complex call dropped at 206.8960750141902
# Simple call dropped at 208.36453501737233
# Simple call dropped at 210.89694588795305
# Simple call dropped at 211.07153371014496
# Complex call dropped at 211.65683292870025
# Simple call dropped at 211.7394125982005
# Simple call dropped at 211.79474391987563
# Simple call dropped at 211.85134572752906
# Complex call dropped at 211.9037393611148
# Simple call dropped at 212.0071585240232
# Simple call dropped at 212.01815807034956
# Simple call dropped at 212.02634558396198
# Simple call dropped at 212.23710268773974
# Complex call dropped at 212.3070391703968
# Complex call dropped at 212.48326124758105
# Simple call dropped at 212.81273516546943
# Simple call dropped at 212.81492726003836
# Simple call dropped at 212.91022257614347
# Complex call dropped at 213.17701708688887
# Complex call dropped at 213.21041119711728
# Complex call dropped at 213.22731879099334
# Simple call dropped at 213.23086622320062
# Simple call dropped at 214.540399443064
# Complex call dropped at 214.58215426911596
# Simple call dropped at 214.6772093911255
# Complex call dropped at 214.68454479022057
# Simple call dropped at 214.7684743142537
# Simple call dropped at 215.23537326431065
# Complex call dropped at 215.38754843812183
# Simple call dropped at 215.39939102554285
# Simple call dropped at 215.4107847563638
# Complex call dropped at 215.4197246192225
# Simple call dropped at 215.63430909387188
# Simple call dropped at 215.6383844987772
# Simple call dropped at 215.6450194732388
# Simple call dropped at 215.64886474982197
# Simple call dropped at 215.65835448878417
# Simple call dropped at 215.7044573930837
# Simple call dropped at 215.71272828744452
# Simple call dropped at 215.8028389777108
# Complex call dropped at 215.84661252755564
# Simple call dropped at 215.92772327371176
# Simple call dropped at 216.00774710488528
# Complex call dropped at 217.63468264302284
# Simple call dropped at 217.68812146212338
# Simple call dropped at 218.2103242919826
# Complex call dropped at 218.78504486127733
# Simple call dropped at 218.95689189884268
# Simple call dropped at 218.96860811893697
# Simple call dropped at 219.79964409918637
# Simple call dropped at 219.9447396731062
# Simple call dropped at 220.02091174190565
# Simple call dropped at 220.11854677853586
# Complex call dropped at 220.13912681457452
# Simple call dropped at 220.17891390839472
# Simple call dropped at 220.28104338595637
# Complex call dropped at 220.3605480002084
# Complex call dropped at 220.47573702523383
# Simple call dropped at 220.4987324482594
# Simple call dropped at 222.95824439144354
# Complex call dropped at 222.99223444140503
# Simple call dropped at 223.10107284944783
# Simple call dropped at 223.1193869281592
# Simple call dropped at 223.14929235086151
# Simple call dropped at 223.1524315920277
# Simple call dropped at 223.18636542616943
# Simple call dropped at 223.2939773503838
# Simple call dropped at 223.49029655719966
# Simple call dropped at 223.49265385492058
# Simple call dropped at 223.64838516066905
# Simple call dropped at 223.7723783853981
# Simple call dropped at 223.7821309240176
# Simple call dropped at 223.78728239739405
# Simple call dropped at 223.82618031702944
# Simple call dropped at 223.9083593833829
# Simple call dropped at 223.9448334481644
# Simple call dropped at 223.94890925548907
# Simple call dropped at 225.09716222488814
# Simple call dropped at 225.13026799412782
# Simple call dropped at 225.3644945150114
# Simple call dropped at 225.40290416460184
# Complex call dropped at 225.42264207099058
# Simple call dropped at 225.46516144375983
# Simple call dropped at 226.81889443291377
# Simple call dropped at 226.83912881154362
# Complex call dropped at 228.819991952243
# Simple call dropped at 228.92184680812142
# Simple call dropped at 228.96651637144183
# Simple call dropped at 229.01297002598238
# Complex call dropped at 229.03003789103641
# Simple call dropped at 229.22392062705416
# Simple call dropped at 230.9992637964205
# Complex call dropped at 231.27133609413826
# Simple call dropped at 231.28753459551186
# Simple call dropped at 231.33776719703943
# Simple call dropped at 231.3612895139354
# Simple call dropped at 235.79660349858702
# Complex call dropped at 235.81211102944445
# Simple call dropped at 235.96331045214123
# Simple call dropped at 236.7337600827716
# Simple call dropped at 236.8973818682533
# Complex call dropped at 237.40018675762244
# Simple call dropped at 237.47129651143834
# Simple call dropped at 237.4860524570423
# Complex call dropped at 237.5086827974156
# Simple call dropped at 237.89343404622784
# Complex call dropped at 237.9005920152356
# Complex call dropped at 237.9465542514369
# Complex call dropped at 237.98728237468583
# Simple call dropped at 238.01209883666436
# Simple call dropped at 238.01463861502472
# Simple call dropped at 238.02483707725747
# Simple call dropped at 242.50621610108627
# Simple call dropped at 250.67373168299335
# Simple call dropped at 250.6769520049719
# Simple call dropped at 251.1162107554132
# Complex call dropped at 251.50949439971396
# Simple call dropped at 251.74281529035454
# Simple call dropped at 251.75553244754767
# Simple call dropped at 251.87865324298258
# Complex call dropped at 251.94325349544982
# Simple call dropped at 251.98623195657296
# Complex call dropped at 252.01789073112934
# Simple call dropped at 252.14932020345998
# Simple call dropped at 252.97868992685412
# Simple call dropped at 253.32122431604088
# Complex call dropped at 253.33441143964097
# Simple call dropped at 253.40660503397726
# Simple call dropped at 253.4504033597941
# Simple call dropped at 253.4537034230402
# Complex call dropped at 253.51190788448528
# Complex call dropped at 253.60907791308034
# Simple call dropped at 253.6658678219406
# Simple call dropped at 253.70842387966164
# Complex call dropped at 253.77583977101654
# Simple call dropped at 254.42215900086703
# Simple call dropped at 254.4474010802618
# Simple call dropped at 254.4980538849374
# Simple call dropped at 254.71714543159564
# Simple call dropped at 254.8033072180696
# Simple call dropped at 257.0228241433017
# Simple call dropped at 257.0695875448193
# Simple call dropped at 257.10819441669787
# Complex call dropped at 257.5717730960422
# Simple call dropped at 257.6192430859541
# Simple call dropped at 257.62415518373075
# Complex call dropped at 257.6668762782754
# Simple call dropped at 257.6696268131265
# Complex call dropped at 257.78897573356966
# Simple call dropped at 257.85870400853605
# Simple call dropped at 257.88601774177664
# Simple call dropped at 258.38346284864735
# Simple call dropped at 258.4162812623337
# Simple call dropped at 258.50783449252543
# Complex call dropped at 259.1887707384421
# Simple call dropped at 259.40769802474114
# Simple call dropped at 259.4179425876614
# Simple call dropped at 259.50849349810477
# Complex call dropped at 259.5738016812632
# Simple call dropped at 259.6396621093935
# Complex call dropped at 261.1147856324132
# Complex call dropped at 261.1275621661425
# Complex call dropped at 261.82594191746983
# Simple call dropped at 262.2808658667212
# Simple call dropped at 262.6082856480641
# Complex call dropped at 262.62753170644316
# Simple call dropped at 262.627993872451
# Simple call dropped at 262.7710718218724
# Complex call dropped at 262.89137709148497
# Complex call dropped at 262.9308284541691
# Simple call dropped at 262.9382122265577
# Simple call dropped at 262.9796509293528
# Complex call dropped at 263.0645211830304
# Simple call dropped at 263.36060203925183
# Simple call dropped at 263.4550094678966
# Simple call dropped at 263.4963461862611
# Simple call dropped at 263.65821393497157
# Simple call dropped at 263.7180078839619
# Complex call dropped at 263.7221594065971
# Simple call dropped at 263.7296993732871
# Simple call dropped at 263.80206724899233
# Simple call dropped at 264.04136533111006
# Complex call dropped at 264.27510824305796
# Simple call dropped at 264.2936575535437
# Simple call dropped at 264.40148230182115
# Complex call dropped at 264.44656270972337
# Simple call dropped at 264.6517929048901
# Simple call dropped at 264.66020779828693
# Simple call dropped at 265.74103346572787
# Simple call dropped at 266.029299994025
# Simple call dropped at 266.29953906030033
# Simple call dropped at 266.3012010564253
# Simple call dropped at 266.36887324224205
# Simple call dropped at 266.5671447279561
# Simple call dropped at 266.57818565850033
# Simple call dropped at 266.69471225298355
# Complex call dropped at 266.9057831645784
# Simple call dropped at 267.0540800291285
# Simple call dropped at 267.06557186763695
# Simple call dropped at 267.0848186515147
# Complex call dropped at 267.0885931168179
# Simple call dropped at 267.0994682526898
# Complex call dropped at 267.34431712556585
# Simple call dropped at 267.3697212531134
# Complex call dropped at 267.4158236100647
# Complex call dropped at 267.56238552612706
# Simple call dropped at 267.613284046416
# Simple call dropped at 267.7029786309604
# Simple call dropped at 267.7520322600907
# Complex call dropped at 267.86777454388937
# Simple call dropped at 267.8853732134393
# Simple call dropped at 267.92154365915263
# Simple call dropped at 267.98593065293875
# Simple call dropped at 268.0055572526639
# Simple call dropped at 268.03679799767434
# Simple call dropped at 268.0541601348583
# Simple call dropped at 268.08384843851553
# Simple call dropped at 268.2328097078521
# Simple call dropped at 269.40194799753016
# Simple call dropped at 269.4416006929878
# Simple call dropped at 269.450845243854
# Simple call dropped at 270.0537718239963
# Complex call dropped at 270.05642803429816
# Simple call dropped at 270.13620276153216
# Simple call dropped at 270.50946100616534
# Simple call dropped at 270.52083395471743
# Simple call dropped at 270.5216291928332
# Simple call dropped at 272.414141315123
# Simple call dropped at 272.947604266061
# Complex call dropped at 273.0144318439019
# Simple call dropped at 273.025899516393
# Simple call dropped at 273.32567981812457
# Simple call dropped at 273.33218763866563
# Complex call dropped at 273.3496755691568
# Complex call dropped at 273.4938551003329
# Simple call dropped at 273.54039592992876
# Complex call dropped at 273.58917046247757
# Simple call dropped at 274.2633816032221
# Simple call dropped at 274.2774786837389
# Simple call dropped at 274.7279172905914
# Simple call dropped at 274.80804603047335
# Complex call dropped at 279.7956055383407
# Simple call dropped at 280.1102683046125
# Simple call dropped at 280.1103850498073
# Simple call dropped at 280.1843441967928
# Simple call dropped at 280.1915872200558
# Complex call dropped at 280.3197451975716
# Simple call dropped at 280.4001511197864
# Complex call dropped at 280.4365044764869
# Simple call dropped at 280.4789357752283
# Complex call dropped at 281.75297531498154
# Complex call dropped at 281.7572297062237
# Simple call dropped at 281.7744175043681
# Simple call dropped at 281.79072514293887
# Complex call dropped at 281.79279651009955
# Simple call dropped at 281.83249189137695
# Simple call dropped at 281.83849054945574
# Simple call dropped at 281.8447218840255
# Simple call dropped at 281.86816969993794
# Complex call dropped at 282.0011285065716
# Simple call dropped at 282.06803111447243
# Complex call dropped at 282.1507668702096
# Simple call dropped at 282.17614958743576
# Simple call dropped at 283.53321735202013
# Simple call dropped at 283.9767137658778
# Simple call dropped at 285.04640362044705
# Simple call dropped at 285.1348356376918
# Simple call dropped at 285.31945546323334
# Complex call dropped at 285.3572254888751
# Simple call dropped at 285.39193865442314
# Complex call dropped at 285.4668066785456
# Simple call dropped at 285.5790035923078
# Simple call dropped at 297.9505539906027
# Simple call dropped at 298.4125607598138
# Simple call dropped at 298.678597726754
# Simple call dropped at 298.70204560705525
# Simple call dropped at 298.91795295181225
# Simple call dropped at 299.0027179109893
# Simple call dropped at 299.0748816628987
# Complex call dropped at 299.1088329436205
# Simple call dropped at 299.2807944781077
# Simple call dropped at 300.8491618701238
# Complex call dropped at 300.8631981349204
# Simple call dropped at 301.2929001134858
# Simple call dropped at 301.3741729422504
# Complex call dropped at 301.60275408421313
# Simple call dropped at 302.6261480743139
# Simple call dropped at 302.6836858035344
# Simple call dropped at 304.01198363941745
# Complex call dropped at 304.0217912502214
# Simple call dropped at 304.0444732907151
# Simple call dropped at 304.09215147204014
# Simple call dropped at 304.1076981612516
# Simple call dropped at 304.125377642699
# Simple call dropped at 304.54582656421593
# Simple call dropped at 305.04445222841093
# Simple call dropped at 305.05680435190305
# Simple call dropped at 305.1082603278174
# Simple call dropped at 305.11951076833566
# Simple call dropped at 306.73519200598986
# Simple call dropped at 306.94946663101575
# Simple call dropped at 306.95188353051185
# Simple call dropped at 307.0422477550978
# Simple call dropped at 307.4352419160627
# Simple call dropped at 307.47818546260635
# Complex call dropped at 307.4855960878143
# Simple call dropped at 307.5533123978822
# Complex call dropped at 307.63641462882146
# Simple call dropped at 307.7128515635162
# Simple call dropped at 307.86488761487544
# Simple call dropped at 307.8737885113607
# Simple call dropped at 308.0197154166039
# Complex call dropped at 308.05778062504345
# Simple call dropped at 308.2803899120951
# Simple call dropped at 308.2863886162277
# Simple call dropped at 308.30367594041
# Complex call dropped at 308.3225439204533
# Simple call dropped at 309.262402759935
# Simple call dropped at 309.2635405803284
# Simple call dropped at 310.9177089313663
# Simple call dropped at 311.05786130668355
# Simple call dropped at 311.39244631810664
# Complex call dropped at 311.40433476348306
# Simple call dropped at 311.77416629990324
# Simple call dropped at 312.9596478351433
# Complex call dropped at 313.0104533929303
# Simple call dropped at 313.3754413889122
# Simple call dropped at 313.9358450696119
# Complex call dropped at 313.9851370743953
# Simple call dropped at 313.99057451499186
# Simple call dropped at 314.2751130000286
# Simple call dropped at 314.30614263102757
# Complex call dropped at 314.32650600303947
# Complex call dropped at 314.327800342433
# Complex call dropped at 315.43019771561495
# Simple call dropped at 316.59173133338913
# Simple call dropped at 316.62786961346325
# Complex call dropped at 318.39377326882465
# Simple call dropped at 318.42928373280984
# Complex call dropped at 318.53317936002
# Complex call dropped at 318.65878168957437
# Simple call dropped at 319.0878424238783
# Complex call dropped at 319.1290564134179
# Complex call dropped at 319.1439936046563
# Simple call dropped at 319.15375394796865
# Complex call dropped at 319.18498174040064
# Simple call dropped at 319.390387852896
# Complex call dropped at 325.05875405232695
# Complex call dropped at 325.1421435233237
# Simple call dropped at 325.20919659250046
# Simple call dropped at 325.32297042715163
# Simple call dropped at 325.33260766043134
# Complex call dropped at 325.4956421284507
# Simple call dropped at 325.71443601003955
# Simple call dropped at 325.75444603395675
# Complex call dropped at 325.7881871078726
# Simple call dropped at 329.99279357953776
# Simple call dropped at 330.0035210952826
# Simple call dropped at 330.0289942502499
# Simple call dropped at 330.09638882361907
# Simple call dropped at 330.107649684374
# Simple call dropped at 330.11053883269335
# Simple call dropped at 330.15758991737164
# Simple call dropped at 330.25520101757377
# Simple call dropped at 333.8659975346187
# Simple call dropped at 333.99737960212497
# Complex call dropped at 334.0633249057936
# Simple call dropped at 334.10568034112885
# Complex call dropped at 334.1425612866468
# Complex call dropped at 334.2071839087019
# Simple call dropped at 334.2245586142296
# Complex call dropped at 334.583748005979
# Simple call dropped at 334.5986144462909
# Simple call dropped at 334.6918166664358
# Simple call dropped at 335.8962847940646
# Complex call dropped at 335.90908488770606
# Simple call dropped at 336.56661038560617
# Simple call dropped at 336.58585411673835
# Simple call dropped at 336.7468299425609
# Simple call dropped at 336.78016380083784
# Complex call dropped at 336.79985810580024
# Complex call dropped at 336.80388230438393
# Simple call dropped at 337.0681953754471
# Simple call dropped at 337.83960024874955
# Simple call dropped at 337.8658259913157
# Simple call dropped at 337.87322099985914
# Simple call dropped at 337.8796178767777
# Simple call dropped at 337.9863295645377
# Complex call dropped at 338.0594537648584
# Simple call dropped at 338.1198131169922
# Simple call dropped at 338.2307570118356
# Simple call dropped at 338.98500303107966
# Simple call dropped at 339.7507584280148
# Simple call dropped at 339.7831225129396
# Complex call dropped at 339.9579228238007
# Simple call dropped at 340.04899883628025
# Complex call dropped at 340.074339323515
# Complex call dropped at 340.10970898342265
# Simple call dropped at 340.16685114571817
# Simple call dropped at 340.18199765270964
# Simple call dropped at 340.2332801120897
# Simple call dropped at 340.2792771146861
# Simple call dropped at 340.2948771097771
# Simple call dropped at 340.5204559145689
# Simple call dropped at 340.5494939883861
# Simple call dropped at 341.5098523290122
# Simple call dropped at 341.5240306359844
# Simple call dropped at 341.55998728292764
# Simple call dropped at 341.62824265041456
# Complex call dropped at 341.6348222951016
# Simple call dropped at 341.84514983492744
# Simple call dropped at 341.9267747766375
# Complex call dropped at 341.96482853841724
# Simple call dropped at 341.9916699509632
# Simple call dropped at 341.99839011959824
# Simple call dropped at 342.01217113428123
# Simple call dropped at 342.1469091649571
# Simple call dropped at 342.1559044973502
# Simple call dropped at 342.2887361975859
# Simple call dropped at 342.5242688871481
# Complex call dropped at 342.5560253672014
# Simple call dropped at 342.67993947208225
# Simple call dropped at 342.85296939003086
# Simple call dropped at 342.8899846875314
# Simple call dropped at 342.9497210280488
# Simple call dropped at 342.99799297219437
# Simple call dropped at 343.1679288286149
# Simple call dropped at 343.2074043083061
# Simple call dropped at 343.2479872200841
# Simple call dropped at 344.0324198084207
# Complex call dropped at 344.04146358528453
# Simple call dropped at 344.1025741139353
# Complex call dropped at 344.1557958750985
# Simple call dropped at 344.61695305076023
# Simple call dropped at 344.6474886817527
# Simple call dropped at 344.9728286125889
# Complex call dropped at 345.04449667817164
# Simple call dropped at 345.2219496904459
# Simple call dropped at 345.2781108499257
# Simple call dropped at 345.33156134803505
# Complex call dropped at 345.8693030841835
# Simple call dropped at 345.8968566089087
# Simple call dropped at 345.9162493485561
# Simple call dropped at 346.7638841345652
# Simple call dropped at 346.8311679309585
# Complex call dropped at 346.95075643715376
# Complex call dropped at 347.01473224973233
# Simple call dropped at 347.04145395462496
# Simple call dropped at 347.07626383895945
# Complex call dropped at 347.1010996448711
# Simple call dropped at 347.19805534209274
# Simple call dropped at 347.2083548662476
# Simple call dropped at 347.23338020706166
# Complex call dropped at 347.3394374797543
# Simple call dropped at 347.4292077224355
# Simple call dropped at 347.44964892200426
# Simple call dropped at 347.4887531892191
# Simple call dropped at 347.4958172198023
# Simple call dropped at 347.60318036070777
# Simple call dropped at 347.6267915575003
# Complex call dropped at 347.6503674708549
# Simple call dropped at 347.7957883211315
# Simple call dropped at 349.1335520212828
# Complex call dropped at 351.38246359708927
# Simple call dropped at 351.4930008356513
# Complex call dropped at 351.92424185299416
# Simple call dropped at 351.92998681701533
# Complex call dropped at 351.93911260951535
# Simple call dropped at 351.9858230665395
# Simple call dropped at 352.05940023041063
# Simple call dropped at 352.0802865281075
# Simple call dropped at 352.1968270565511
# Simple call dropped at 352.23143452635406
# Simple call dropped at 352.4964871802591
# Simple call dropped at 352.5401985971459
# Complex call dropped at 352.65140315720265
# Simple call dropped at 352.9796302289171
# Simple call dropped at 353.1182939303282
# Complex call dropped at 353.13630709010846
# Complex call dropped at 353.20848801196075
# Complex call dropped at 353.2683442415778
# Simple call dropped at 353.39126238144956
# Simple call dropped at 353.4550765351509
# Simple call dropped at 353.492902588969
# Complex call dropped at 353.68939521040716
# Complex call dropped at 353.72199012768624
# Simple call dropped at 353.973229459499
# Simple call dropped at 353.9840292873186
# Simple call dropped at 354.0643119372929
# Simple call dropped at 354.0986183522181
# Simple call dropped at 354.1278835300619
# Simple call dropped at 354.44803301548376
# Simple call dropped at 354.45631202829895
# Complex call dropped at 354.4617186225556
# Complex call dropped at 355.44989286534803
# Complex call dropped at 355.50926649352317
# Complex call dropped at 355.72089233369087
# Simple call dropped at 356.24059401108445
# Simple call dropped at 356.28416644249137
# Simple call dropped at 356.2857411396479
# Simple call dropped at 364.5167658059463
# Complex call dropped at 364.539704451809
# Complex call dropped at 364.64136728229045
# Complex call dropped at 364.7944050238153
# Simple call dropped at 365.0724656340603
# Simple call dropped at 365.07588767705613
# Complex call dropped at 365.5234044584798
# Simple call dropped at 365.541430837887
# Simple call dropped at 366.5904345200554
# Complex call dropped at 366.62730474461625
# Complex call dropped at 367.5355899296566
# Simple call dropped at 367.5904427154855
# Simple call dropped at 367.6738161637962
# Simple call dropped at 367.68686933486384
# Simple call dropped at 367.7207067119709
# Simple call dropped at 367.7571111244697
# Simple call dropped at 367.8710553785729
# Simple call dropped at 367.92083087909225
# Simple call dropped at 368.05510874366985
# Complex call dropped at 368.0757359777995
# Complex call dropped at 368.16300703217894
# Simple call dropped at 368.46514393745514
# Simple call dropped at 368.4667832584463
# Complex call dropped at 368.4903388013356
# Complex call dropped at 368.53713143642784
# Complex call dropped at 368.89071032251593
# Simple call dropped at 369.2991190753202
# Simple call dropped at 369.3111356766906
# Simple call dropped at 369.42660229634635
# Simple call dropped at 369.4592997552726
# Simple call dropped at 369.58369434278575
# Complex call dropped at 369.59972275594924
# Simple call dropped at 369.6281989814291
# Complex call dropped at 369.63264405676654
# Simple call dropped at 369.6417833705038
# Simple call dropped at 369.6603780734771
# Simple call dropped at 369.66805481891646
# Simple call dropped at 369.69149963544567
# Complex call dropped at 369.7036523494884
# Simple call dropped at 369.76236184889603
# Simple call dropped at 369.98195618312377
# Complex call dropped at 369.9914118464613
# Simple call dropped at 373.4355689826556
# Simple call dropped at 373.4463832602088
# Simple call dropped at 373.6591744339702
# Complex call dropped at 373.7985217896123
# Complex call dropped at 376.17544091393194
# Simple call dropped at 376.4278725973978
# Simple call dropped at 376.4919925306612
# Simple call dropped at 376.5040207477045
# Simple call dropped at 376.581062588689
# Complex call dropped at 376.6378523572852
# Simple call dropped at 376.64532129086535
# Simple call dropped at 376.68324198928707
# Simple call dropped at 376.76248423511146
# Complex call dropped at 376.8514928002169
# Simple call dropped at 376.86747522198925
# Simple call dropped at 376.98257381451356
# Simple call dropped at 377.0032053629836
# Simple call dropped at 377.01479210936185
# Complex call dropped at 377.0251324673353
# Complex call dropped at 377.07625337859463
# Complex call dropped at 377.09340613356187
# Complex call dropped at 377.1133236181925
# Complex call dropped at 377.2167723641177
# Complex call dropped at 377.6809458758569
# Simple call dropped at 377.70216072812286
# Simple call dropped at 377.79235662084346
# Simple call dropped at 377.7952586804454
# Simple call dropped at 377.9964107381347
# Simple call dropped at 378.0147871709631
# Simple call dropped at 378.0315458216306
# Simple call dropped at 378.0444011741261
# Simple call dropped at 378.04729363285514
# Simple call dropped at 384.113106819584
# Simple call dropped at 384.2043987021573
# Simple call dropped at 384.2135467280494
# Complex call dropped at 384.28359216516293
# Simple call dropped at 384.34007398774133
# Simple call dropped at 384.4086161686175
# Complex call dropped at 384.5301551786398
# Complex call dropped at 384.6244192265596
# Simple call dropped at 384.77612031064405
# Simple call dropped at 384.9076152348292
# Simple call dropped at 384.9180290938103
# Simple call dropped at 385.1314169909899
# Simple call dropped at 385.1731215538321
# Complex call dropped at 385.1803547869562
# Simple call dropped at 385.2867706062528
# Simple call dropped at 385.3577522206948
# Complex call dropped at 385.6533024493539
# Simple call dropped at 385.68447466999186
# Simple call dropped at 385.6865113931706
# Simple call dropped at 396.8068254736264
# Simple call dropped at 396.81036914084535
# Complex call dropped at 396.90509939790775
# Simple call dropped at 397.17427026153797
# Simple call dropped at 397.1961377067532
# Complex call dropped at 397.4395495132877
# Simple call dropped at 397.45336262666325
# Simple call dropped at 397.5784862844984
# Complex call dropped at 397.58801045991936
# Simple call dropped at 399.0573407455449
# Simple call dropped at 399.10182583671957
# Complex call dropped at 399.121490482551
# Simple call dropped at 399.184801152196
# Simple call dropped at 399.26118572313914
# Simple call dropped at 401.0064932343605
# Simple call dropped at 401.04786400394863
# Simple call dropped at 401.0617114809197
# Simple call dropped at 401.34473882588003
# Complex call dropped at 401.3592645900664
# Simple call dropped at 401.3886975110461
# Simple call dropped at 401.46902005022065
# Simple call dropped at 401.4845390056578
# Complex call dropped at 401.5120960497497
# Simple call dropped at 408.9565713674826
# Simple call dropped at 409.0933268777222
# Simple call dropped at 409.1027622320836
# Simple call dropped at 409.10920630758693
# Simple call dropped at 409.1481586587452
# Simple call dropped at 409.16209558896765
# Simple call dropped at 409.2968247442261
# Simple call dropped at 409.2976324159389
# Simple call dropped at 409.2987606205925
# Simple call dropped at 409.6493735516706
# Complex call dropped at 409.6837093674422
# Simple call dropped at 409.82160139414873
# Simple call dropped at 409.83092326307377
# Simple call dropped at 409.8417636029661
# Simple call dropped at 409.95832343781956
# Complex call dropped at 409.9921882794049
# Complex call dropped at 409.99295798565623
# Simple call dropped at 410.4348200225327
# Complex call dropped at 410.77507180004653
# Complex call dropped at 410.7908327761552
# Complex call dropped at 410.83224943181915
# Simple call dropped at 410.8651600457937
# Complex call dropped at 410.9097957222813
# Complex call dropped at 410.94524427575254
# Simple call dropped at 414.6232757512752
# Simple call dropped at 414.69501765553497
# Simple call dropped at 414.7285228210048
# Simple call dropped at 414.7465345164904
# Simple call dropped at 414.75786550885965
# Complex call dropped at 414.81255637372476
# Complex call dropped at 414.86455074174575
# Complex call dropped at 415.1783739080823
# Complex call dropped at 417.2642968747341
# Simple call dropped at 417.2648780939039
# Complex call dropped at 420.672511315227
# Simple call dropped at 420.71273596496894
# Complex call dropped at 421.53120441338336
# Simple call dropped at 421.5787734208697
# Complex call dropped at 421.6003887702695
# Simple call dropped at 421.6210011074108
# Simple call dropped at 421.97118160384883
# Simple call dropped at 421.9900584824473
# Simple call dropped at 422.0159749573687
# Simple call dropped at 422.1086778792873
# Complex call dropped at 422.1317891139439
# Complex call dropped at 422.1734572981869
# Complex call dropped at 422.4074844560212
# Simple call dropped at 422.9801849818423
# Simple call dropped at 423.01912126544187
# Complex call dropped at 423.0768565995235
# Complex call dropped at 423.33592705218774
# Complex call dropped at 423.3678747145969
# Simple call dropped at 423.54243844821866
# Simple call dropped at 423.5861013143598
# Complex call dropped at 423.5912246360251
# Complex call dropped at 423.6093070979276
# Complex call dropped at 425.0611230668933
# Simple call dropped at 425.07800614218417
# Complex call dropped at 425.11992136409543
# Simple call dropped at 425.1446315590711
# Simple call dropped at 425.71183456544065
# Complex call dropped at 425.7952350463659
# Complex call dropped at 425.81774041244194
# Simple call dropped at 425.82788257491563
# Simple call dropped at 425.8782578222195
# Simple call dropped at 426.05682335236986
# Simple call dropped at 426.3066522488171
# Simple call dropped at 426.31511689176034
# Simple call dropped at 426.7068554969041
# Simple call dropped at 426.7366040649692
# Simple call dropped at 427.10872755938436
# Complex call dropped at 427.117146915285
# Complex call dropped at 427.25193682862607
# Complex call dropped at 427.2574785262184
# Complex call dropped at 429.1968452767191
# Simple call dropped at 429.3857062869983
# Simple call dropped at 429.61649172160645
# Simple call dropped at 432.4337060642266
# Simple call dropped at 432.4394257709621
# Simple call dropped at 432.4468140440813
# Simple call dropped at 432.89922536557856
# Complex call dropped at 432.95737797570763
# Simple call dropped at 433.06999008269986
# Simple call dropped at 433.1690119220575
# Complex call dropped at 436.7841138867931
# Complex call dropped at 436.83405592634796
# Simple call dropped at 437.07626770642725
# Complex call dropped at 437.2358864953114
# Simple call dropped at 437.25319659520335
# Simple call dropped at 438.49617768458137
# Complex call dropped at 440.40877101490804
# Simple call dropped at 441.9948511542885
# Simple call dropped at 442.17324330772163
# Simple call dropped at 442.91765718364934
# Simple call dropped at 442.943838411782
# Simple call dropped at 442.9459211829986
# Simple call dropped at 442.96648686144385
# Simple call dropped at 443.02784059020826
# Simple call dropped at 443.02987692261854
# Complex call dropped at 443.0764782797379
# Simple call dropped at 443.1243147335698
# Simple call dropped at 443.15226230698414
# Simple call dropped at 443.15661716854515
# Complex call dropped at 443.27829540142824
# Simple call dropped at 443.7922111393316
# Simple call dropped at 443.79577733990476
# Simple call dropped at 443.82584743730695
# Complex call dropped at 443.8556068885354
# Complex call dropped at 443.89886367647574
# Complex call dropped at 444.06732999578895
# Simple call dropped at 444.0816463381215
# Complex call dropped at 444.1754457926349
# Complex call dropped at 444.2083373550046
# Simple call dropped at 444.2273340474698
# Simple call dropped at 444.2519287742814
# Simple call dropped at 444.25763904636017
# Complex call dropped at 444.3667346986596
# Simple call dropped at 444.420794538001
# Complex call dropped at 444.428449848898
# Complex call dropped at 444.4421246913984
# Simple call dropped at 444.4757165234864
# Complex call dropped at 444.7045015270353
# Simple call dropped at 445.058307430142
# Complex call dropped at 445.26077704495384
# Simple call dropped at 445.3039579055586
# Simple call dropped at 446.2163154778252
# Simple call dropped at 446.28142740480115
# Simple call dropped at 446.31900861232424
# Complex call dropped at 446.31964369246907
# Complex call dropped at 446.42834497674573
# Simple call dropped at 446.43207753671174
# Simple call dropped at 446.4391283497863
# Simple call dropped at 446.4539007592298
# Simple call dropped at 446.5085829324621
# Complex call dropped at 446.508802947791
# Complex call dropped at 446.5225273779297
# Complex call dropped at 446.59789037364334
# Simple call dropped at 447.4460336777604
# Complex call dropped at 447.47052721793574
# Simple call dropped at 447.4790522029915
# Complex call dropped at 447.4876594641423
# Complex call dropped at 447.48936468561743
# Simple call dropped at 447.6196727121458
# Complex call dropped at 447.6448315747631
# ...
# Simple call dropped at 598.950504872376
# Simple call dropped at 599.0453684658302
# Simple call dropped at 599.1515096304344
# Simple call dropped at 599.2703569652211
# Complex call dropped at 599.307803090741
# Simple call dropped at 599.3133849550013
# Complex call dropped at 599.4871859619545
# Complex call dropped at 599.49067367536
# Simple call dropped at 599.569359062148
# Simple call dropped at 599.6062165176263
# Simple call dropped at 599.7565687657693
# Simple call dropped at 599.7742917573543
# Complex call dropped at 600.1805891152434
# Simple call dropped at 603.0264309644864
# Complex call dropped at 604.941269568861
# Simple call dropped at 604.9725537969351
# Simple call dropped at 604.9909415511755
# Complex call dropped at 605.0846993040426
# Simple call dropped at 605.1627554402851
# Simple call dropped at 605.1775417606772
# Simple call dropped at 605.8500278526385
# Complex call dropped at 606.2346411233132
# Complex call dropped at 607.6069426082622
# Simple call dropped at 607.6195634602476
# Simple call dropped at 607.8847777751071
# Simple call dropped at 607.9419322195674
# Simple call dropped at 609.0147050477323
# Simple call dropped at 609.2179679536841
# Simple call dropped at 609.2387811670089
# Complex call dropped at 609.3364079266065
# Complex call dropped at 609.3551448862547
# Simple call dropped at 609.3685652023099
# Simple call dropped at 609.3998601070523
# Simple call dropped at 609.4583913364221
# Complex call dropped at 609.7384575965018
# Complex call dropped at 609.7936428499605
# Simple call dropped at 609.8007223864446
# Simple call dropped at 609.8015965582523
# Complex call dropped at 610.1184578121586
# Complex call dropped at 610.1270941290776
# Complex call dropped at 610.1392716071229
# Simple call dropped at 610.1847237259293
# Complex call dropped at 610.2907527724777
# Simple call dropped at 610.4358624216579
# Simple call dropped at 610.4395003958963
# Simple call dropped at 610.4725929390073
# Complex call dropped at 610.6565372651228
# Simple call dropped at 610.7940924796474
# Simple call dropped at 610.8369474649219
# Simple call dropped at 611.6379617449248
# Simple call dropped at 612.1953520791874
# Complex call dropped at 613.5802664654286
# Simple call dropped at 613.6117759865474
# Simple call dropped at 613.8697763206549
# Simple call dropped at 613.9267584334686
# Simple call dropped at 613.951864909604
# Simple call dropped at 614.7029245516662
# Simple call dropped at 614.8396015897505
# Simple call dropped at 615.2371342436185
# Complex call dropped at 615.36513268276
# Simple call dropped at 615.4984702026874
# Simple call dropped at 615.6193877389334
# Simple call dropped at 615.6223665836903
# Simple call dropped at 615.6526948888657
# Complex call dropped at 615.6640508868201
# Simple call dropped at 615.6721555569109
# Simple call dropped at 615.7337927753548
# Simple call dropped at 615.7393940185924
# Simple call dropped at 615.7960663865491
# Complex call dropped at 615.8042370844352
# Complex call dropped at 616.3468419196894
# Simple call dropped at 616.4949619719539
# Simple call dropped at 616.5063486847489
# Simple call dropped at 616.5182648064413
# Simple call dropped at 616.5438660368517
# Simple call dropped at 616.5590787102029
# Simple call dropped at 616.5624388198001
# Simple call dropped at 616.5877526100713
# Simple call dropped at 616.6764872938384
# Simple call dropped at 616.6920534913339
# Simple call dropped at 616.8620018727431
# Simple call dropped at 616.9693300854315
# Complex call dropped at 616.9919352492718
# Simple call dropped at 617.0060143387949
# Simple call dropped at 617.0066268178359
# Complex call dropped at 617.1275020232338
# Simple call dropped at 617.2223039385129
# Simple call dropped at 617.2487712098945
# Complex call dropped at 617.4926053910577
# Simple call dropped at 617.509623114865
# Simple call dropped at 617.5147348390038
# Simple call dropped at 617.5696659436646
# Simple call dropped at 618.7509072376462
# Simple call dropped at 619.0285645921654
# Complex call dropped at 619.1007565257752
# Simple call dropped at 619.1059524959015
# Complex call dropped at 619.1068535354609
# Simple call dropped at 619.1143426828577
# Simple call dropped at 619.1481570732802
# Complex call dropped at 619.162636329542
# Simple call dropped at 620.0961040856193
# Complex call dropped at 620.1092508504206
# Simple call dropped at 620.635820527262
# Simple call dropped at 620.6707404139893
# Simple call dropped at 620.6908784261637
# Simple call dropped at 620.7774692021668
# Simple call dropped at 620.9177080045426
# Simple call dropped at 621.1586958962099
# Simple call dropped at 621.1669565773442
# Complex call dropped at 621.2418340051025
# Simple call dropped at 621.3805641652207
# Simple call dropped at 621.3925472550508
# Simple call dropped at 621.6760252533298
# Simple call dropped at 621.7407450258178
# Simple call dropped at 621.7506386574395
# Simple call dropped at 621.7537852722986
# Simple call dropped at 621.7631011729873
# Complex call dropped at 622.0779036421557
# Complex call dropped at 622.233423689077
# Complex call dropped at 622.7501039356795
# Simple call dropped at 622.7515747215824
# Simple call dropped at 622.7996436003338
# Simple call dropped at 622.8888972181533
# Complex call dropped at 623.0499273724068
# Complex call dropped at 623.05654133817
# Complex call dropped at 623.1534809921245
# Simple call dropped at 623.2011826601581
# Simple call dropped at 623.2048986341483
# Simple call dropped at 623.2479778743684
# Simple call dropped at 623.3592707078724
# Simple call dropped at 623.4999766988916
# Simple call dropped at 623.5780028229309
# Simple call dropped at 625.5891404461534
# Simple call dropped at 625.6300868908896
# Complex call dropped at 625.6917352117365
# Simple call dropped at 625.6951201707965
# Simple call dropped at 625.7248670825654
# Simple call dropped at 626.1667294439653
# Simple call dropped at 626.2212279485854
# Simple call dropped at 626.2460966031483
# Simple call dropped at 626.2695101999565
# Simple call dropped at 626.2738427488962
# Simple call dropped at 626.4857483013453
# Simple call dropped at 626.5460574232329
# Simple call dropped at 626.6421368511809
# Simple call dropped at 626.6744864148408
# Complex call dropped at 628.486796756889
# Simple call dropped at 628.5025970997997
# Simple call dropped at 628.5870829721525
# Simple call dropped at 632.7694627318836
# Complex call dropped at 634.6936840179255
# Complex call dropped at 634.7681874246242
# Simple call dropped at 634.8160513162709
# Simple call dropped at 634.8433070525158
# Simple call dropped at 634.9783263950593
# Complex call dropped at 634.9819077661862
# Simple call dropped at 634.995525956306
# Simple call dropped at 635.0060333966806
# Simple call dropped at 635.0488036333124
# Simple call dropped at 635.0798410680696
# Simple call dropped at 635.1933808159862
# Simple call dropped at 635.3219603684199
# Complex call dropped at 635.379739988083
# Simple call dropped at 635.4310655485235
# Simple call dropped at 635.4715834837402
# Complex call dropped at 635.8042504069786
# Simple call dropped at 635.9670425949631
# Complex call dropped at 636.0442912961947
# Complex call dropped at 636.0544444351341
# Complex call dropped at 636.0731891209799
# Complex call dropped at 636.1377881081138
# Simple call dropped at 636.1699753210703
# Simple call dropped at 638.1111881195503
# Complex call dropped at 638.1301467360964
# Simple call dropped at 638.1564708211355
# Simple call dropped at 639.2275660520353
# Simple call dropped at 639.2292430722284
# Simple call dropped at 639.7201171621333
# Simple call dropped at 639.7328834081579
# Complex call dropped at 639.8105232431342
# Complex call dropped at 640.9405989013392
# Simple call dropped at 641.5594679763303
# Simple call dropped at 642.5666814952008
# Simple call dropped at 642.5881467690513
# Simple call dropped at 642.628434898659
# Simple call dropped at 642.6423228040998
# Simple call dropped at 642.945943204441
# Complex call dropped at 642.9585082646662
# Simple call dropped at 642.9586423483706
# Simple call dropped at 643.2079560915014
# Complex call dropped at 643.5956523103335
# Simple call dropped at 643.6479619601058
# Simple call dropped at 643.6682953641936
# Simple call dropped at 643.7454595084973
# Simple call dropped at 643.7467990290887
# Simple call dropped at 643.7639191669092
# Complex call dropped at 643.8521545965408
# Simple call dropped at 643.9655754999092
# Complex call dropped at 643.9920902355764
# Simple call dropped at 643.9982448475782
# Simple call dropped at 644.0148910223747
# Simple call dropped at 644.0191488457056
# Complex call dropped at 644.1149643671591
# Complex call dropped at 644.215280477961
# Simple call dropped at 654.5591798311623
# Complex call dropped at 654.5992428706734
# Complex call dropped at 654.7228491370332
# Simple call dropped at 654.7669167327697
# Simple call dropped at 659.049501665875
# Complex call dropped at 659.2450013785902
# Simple call dropped at 660.6629223790877
# Simple call dropped at 660.6926190729753
# Simple call dropped at 660.7094368083737
# Simple call dropped at 660.9821894179029
# Simple call dropped at 661.0027903543481
# Simple call dropped at 661.0380949570376
# Simple call dropped at 661.2471320373041
# Complex call dropped at 661.8553475055685
# Simple call dropped at 661.9079906211458
# Simple call dropped at 661.9082587941344
# Simple call dropped at 661.9427467550935
# Simple call dropped at 662.0006524453217
# Simple call dropped at 662.0896961446188
# Simple call dropped at 662.3293129227255
# Simple call dropped at 662.3452814198415
# Simple call dropped at 662.3865841701579
# Simple call dropped at 662.4137892118392
# Simple call dropped at 662.446085632554
# Simple call dropped at 662.6137238080246
# Complex call dropped at 662.6304168048221
# Simple call dropped at 662.6772885651035
# Complex call dropped at 662.6911385152229
# Simple call dropped at 662.723743977042
# Simple call dropped at 664.4327193191983
# Simple call dropped at 666.7266045030317
# Simple call dropped at 666.838075165884
# Simple call dropped at 669.2772176370172
# Simple call dropped at 669.4802777759967
# Simple call dropped at 669.4849390094416
# Simple call dropped at 669.5611045144352
# Simple call dropped at 669.5752455762138
# Simple call dropped at 669.7979857533338
# Simple call dropped at 669.8036390828624
# Simple call dropped at 669.8181024894432
# Simple call dropped at 669.8316675639466
# Simple call dropped at 669.8467548682058
# Complex call dropped at 678.4664274761299
# Simple call dropped at 678.5410685418465
# Simple call dropped at 678.6266599919231
# Simple call dropped at 678.749584945203
# Simple call dropped at 678.9074420071236
# Simple call dropped at 678.9080045317677
# Simple call dropped at 678.9317460071588
# Complex call dropped at 678.9602780590814
# Simple call dropped at 679.6186137646084
# Simple call dropped at 679.6996885503439
# Simple call dropped at 679.705824206094
# Simple call dropped at 679.7438801753839
# Simple call dropped at 679.7473093374028
# Simple call dropped at 679.8326348808479
# Complex call dropped at 679.8785152262997
# Simple call dropped at 679.8822358202084
# Simple call dropped at 679.8822429394055
# Simple call dropped at 679.9085754794345
# Simple call dropped at 679.9556019521943
# Simple call dropped at 680.0045072618843
# Complex call dropped at 680.0657417066369
# Complex call dropped at 680.1168473346877
# Simple call dropped at 680.4212875999885
# Simple call dropped at 680.5316971781021
# Complex call dropped at 680.9770484337431
# Complex call dropped at 681.0134628399439
# Simple call dropped at 681.3020247844174
# Simple call dropped at 681.3021461746628
# Simple call dropped at 681.3375738696672
# Complex call dropped at 681.5118821556296
# Complex call dropped at 681.57225783753
# Simple call dropped at 681.7251172796075
# Simple call dropped at 681.7489660301949
# Complex call dropped at 681.8352549550141
# Simple call dropped at 681.8404517769447
# Simple call dropped at 681.8937989094278
# Simple call dropped at 681.8981241051121
# Simple call dropped at 681.8990717996979
# Simple call dropped at 681.9225832506249
# Complex call dropped at 681.9706691480387
# Complex call dropped at 681.9732054549793
# Simple call dropped at 682.0696964764427
# Complex call dropped at 682.0727863708696
# Complex call dropped at 682.076495551659
# Simple call dropped at 682.0966436843672
# Simple call dropped at 682.1738823424241
# Complex call dropped at 694.3582054427438
# Complex call dropped at 694.5832362303913
# Simple call dropped at 694.6052985306635
# Complex call dropped at 694.6760406273403
# Simple call dropped at 695.7449948967915
# Simple call dropped at 695.9055302603876
# Complex call dropped at 695.9122460404438
# Simple call dropped at 696.2551116249846
# Simple call dropped at 696.3794449254643
# Complex call dropped at 702.6451112943014
# Simple call dropped at 702.8101752494878
# Complex call dropped at 702.8286018817255
# Simple call dropped at 702.9300466393073
# Simple call dropped at 702.9315231628227
# Simple call dropped at 702.9526851097097
# Simple call dropped at 702.9611296290213
# Simple call dropped at 703.1278008189314
# Simple call dropped at 703.1911799274233
# Complex call dropped at 703.2777724183863
# Complex call dropped at 703.3019075888654
# Complex call dropped at 703.3757619697883
# Simple call dropped at 703.578485481245
# Simple call dropped at 703.9540863856089
# Complex call dropped at 704.038493566039
# Simple call dropped at 704.0653322192393
# Simple call dropped at 704.1316223524177
# Simple call dropped at 704.1467238345526
# Simple call dropped at 705.9093799561639
# Simple call dropped at 706.4562468181856
# Simple call dropped at 706.4759041594493
# Simple call dropped at 706.5360653469854
# Simple call dropped at 706.6497988378818
# Complex call dropped at 706.79395586628
# Simple call dropped at 706.8079087902415
# Simple call dropped at 706.8275626438791
# Simple call dropped at 706.8530582491311
# Complex call dropped at 707.1445877660994
# Simple call dropped at 707.2420298207085
# Complex call dropped at 707.3757817161105
# Simple call dropped at 707.376033190262
# Simple call dropped at 707.5046516947776
# Simple call dropped at 707.6153979652822
# Simple call dropped at 707.6230939570562
# Simple call dropped at 707.8127472015863
# Simple call dropped at 707.8825126055926
# Simple call dropped at 708.0122147986971
# Complex call dropped at 708.0223455432518
# Simple call dropped at 708.1130308073588
# Complex call dropped at 708.3424695432556
# Simple call dropped at 708.7754634255183
# Complex call dropped at 708.8386994501137
# Simple call dropped at 708.853392363802
# Simple call dropped at 708.857335898854
# Complex call dropped at 709.2684008298168
# Simple call dropped at 709.3151893269039
# Complex call dropped at 709.3851730132047
# Simple call dropped at 709.5168214285571
# Simple call dropped at 710.1111623592573
# Complex call dropped at 710.1294351126462
# Simple call dropped at 710.170455403077
# Complex call dropped at 710.1763864012655
# Simple call dropped at 710.6447543687146
# Simple call dropped at 711.2521092484758
# Simple call dropped at 711.2889309311666
# Simple call dropped at 711.3487821821504
# Complex call dropped at 711.3559774666212
# Simple call dropped at 711.3742585575067
# Simple call dropped at 711.4454670599346
# Simple call dropped at 711.4744131815833
# Simple call dropped at 711.679818356215
# Simple call dropped at 713.9925927862012
# Simple call dropped at 714.3981408295845
# Simple call dropped at 714.6631840308495
# Complex call dropped at 714.8248721714979
# Simple call dropped at 714.9070910205563
# Complex call dropped at 714.9583109141532
# Simple call dropped at 717.331885437643
# Simple call dropped at 717.3588080937448
# Simple call dropped at 717.401879155579
# Simple call dropped at 717.4286028607266
# Simple call dropped at 717.4308753819791
# Simple call dropped at 717.4458229997895
# Simple call dropped at 717.4746704401445
# Simple call dropped at 717.5048763506597
# Simple call dropped at 717.5468159911362
# Simple call dropped at 717.5593954667625
# Complex call dropped at 717.9707624703559
# Complex call dropped at 718.0993479577019
# Simple call dropped at 718.1938171037046
# Simple call dropped at 718.2233771466854
# Simple call dropped at 718.2272125008017
# Simple call dropped at 718.247526640705
# Simple call dropped at 718.4429257311231
# Simple call dropped at 718.5561331431231
# Simple call dropped at 718.5900706876274
# Simple call dropped at 718.5955419167897

# %%
results_month_2 = run_simulation(alt_simple_policy, alt_complex_policy, sim_time=720)
# Plot the results for the month
plot_queue_length_over_time(results_month_2)
plot_waiting_times_by_queue(results_month_2)
# Out:
# Complex call dropped at 19.03035778530023
# Simple call dropped at 19.146538894356276
# Simple call dropped at 19.154093081194628
# Simple call dropped at 19.77379086317315
# Complex call dropped at 19.800624026854397
# Complex call dropped at 19.818524295248732
# Simple call dropped at 20.127854394511637
# Simple call dropped at 20.200455329366804
# Simple call dropped at 20.253876090926106
# Simple call dropped at 20.316958263115865
# Simple call dropped at 20.363146747972362
# Simple call dropped at 20.482101036870137
# Simple call dropped at 20.745799429720975
# Simple call dropped at 20.76378421519112
# Simple call dropped at 20.786480122290747
# Simple call dropped at 36.90653580577404
# Complex call dropped at 37.02596517974087
# Simple call dropped at 37.1056456113894
# Simple call dropped at 37.24283000715402
# Simple call dropped at 37.38500473454682
# Simple call dropped at 37.4664562050324
# Simple call dropped at 37.970585322199085
# Simple call dropped at 37.99077205965377
# Simple call dropped at 38.218415616279366
# Simple call dropped at 38.300288081087864
# Simple call dropped at 38.56219565443762
# Complex call dropped at 38.56876127017257
# Simple call dropped at 38.57449671320188
# Complex call dropped at 38.76650939738257
# Complex call dropped at 38.775154010164485
# Complex call dropped at 38.7789378871219
# Simple call dropped at 38.96768285553645
# Simple call dropped at 39.66161122048385
# Complex call dropped at 39.791581957338956
# Complex call dropped at 39.84548984699352
# Complex call dropped at 39.877158723482
# Simple call dropped at 39.910550605429904
# Complex call dropped at 39.92110654479165
# Simple call dropped at 39.98740945976933
# Complex call dropped at 40.2067093093961
# Simple call dropped at 40.250024038136274
# Simple call dropped at 40.36894821755775
# Complex call dropped at 40.524759415168475
# Complex call dropped at 40.53890534632523
# Simple call dropped at 40.70049577058736
# Simple call dropped at 40.707148657858816
# Complex call dropped at 41.143241701386145
# Simple call dropped at 41.21660736885031
# Complex call dropped at 41.22082375032044
# Simple call dropped at 41.221929926430334
# Complex call dropped at 41.24267556630814
# Complex call dropped at 42.13569771797818
# Complex call dropped at 42.20978929890696
# Complex call dropped at 42.30432812592753
# Simple call dropped at 42.32197875035894
# Simple call dropped at 42.67335649546426
# Simple call dropped at 42.71088601379203
# Simple call dropped at 42.727450316108175
# Complex call dropped at 42.72817029610641
# Simple call dropped at 42.74753728549489
# Simple call dropped at 43.59162984411616
# Complex call dropped at 43.80206163608718
# Simple call dropped at 44.07021190108961
# Simple call dropped at 44.11030026989447
# Simple call dropped at 44.32665609220203
# Simple call dropped at 44.35062995508366
# Simple call dropped at 44.503428390018826
# Simple call dropped at 44.51244856862566
# Complex call dropped at 44.6346693343154
# Simple call dropped at 44.668290520240234
# Simple call dropped at 44.69625392621719
# Complex call dropped at 45.22960491944239
# Complex call dropped at 45.235323407684945
# Simple call dropped at 45.67805112793353
# Complex call dropped at 45.770602181054315
# Simple call dropped at 45.779934387911126
# Simple call dropped at 45.804568721465415
# Simple call dropped at 45.92265306567239
# Complex call dropped at 45.94628106064442
# Complex call dropped at 46.01794523292695
# Complex call dropped at 46.041444874611905
# Simple call dropped at 46.04724487377681
# Simple call dropped at 46.51135283237611
# Complex call dropped at 46.512530024370136
# Simple call dropped at 46.59549428246308
# Simple call dropped at 46.61987436327121
# Simple call dropped at 46.62123899510961
# Simple call dropped at 47.42635253563236
# Simple call dropped at 47.80231210831761
# Simple call dropped at 47.81338974014836
# Simple call dropped at 47.851631092181776
# Simple call dropped at 48.422161099428266
# Complex call dropped at 48.580909847660855
# Complex call dropped at 48.59760115067822
# Simple call dropped at 48.5984391370551
# Simple call dropped at 48.62893897571254
# Simple call dropped at 48.80698641434246
# Complex call dropped at 48.81390453371877
# Complex call dropped at 48.96504425455963
# Simple call dropped at 48.977028650291935
# Simple call dropped at 51.803337625031574
# Complex call dropped at 51.842018795868604
# Complex call dropped at 52.1321284049288
# Simple call dropped at 52.35458673843776
# Simple call dropped at 52.36957948474377
# Simple call dropped at 52.4020447368653
# Complex call dropped at 52.43519312061913
# Simple call dropped at 52.505009237910556
# Simple call dropped at 52.90963113950295
# Simple call dropped at 53.64846237392996
# Simple call dropped at 53.67788035301399
# Simple call dropped at 53.68419473760898
# Simple call dropped at 53.68934331176257
# Simple call dropped at 53.73760283499954
# Complex call dropped at 53.85735318318105
# Simple call dropped at 53.92960988809355
# Simple call dropped at 54.1055952240309
# Simple call dropped at 54.144169664418065
# Simple call dropped at 54.19652339682077
# Complex call dropped at 54.199227856874145
# Simple call dropped at 54.22246116925006
# Simple call dropped at 54.230946516554035
# Complex call dropped at 54.256210075247694
# Simple call dropped at 54.259512262561145
# Simple call dropped at 54.353636321393914
# Complex call dropped at 54.4324919391569
# Complex call dropped at 54.57042879265496
# Simple call dropped at 54.60304346245915
# Simple call dropped at 54.60499755343871
# Complex call dropped at 54.64421892704877
# Complex call dropped at 55.19725071110856
# Simple call dropped at 56.47626819800387
# Simple call dropped at 57.24549623818237
# Simple call dropped at 57.53780399234785
# Simple call dropped at 57.63553716150537
# Simple call dropped at 57.67955988013712
# Simple call dropped at 61.74456369638767
# Simple call dropped at 61.76173365468408
# Complex call dropped at 61.855044857561126
# Simple call dropped at 61.872912774046284
# Simple call dropped at 61.95889572051025
# Simple call dropped at 62.12047571118419
# Simple call dropped at 62.30992917284317
# Complex call dropped at 62.312743902519124
# Simple call dropped at 62.317490191301296
# Simple call dropped at 62.33451508603454
# Simple call dropped at 62.34714297155576
# Simple call dropped at 62.37972406580908
# Simple call dropped at 62.40348086316341
# Simple call dropped at 62.42866143328534
# Simple call dropped at 63.747107381565115
# Simple call dropped at 63.81206328334821
# Simple call dropped at 63.8637799614048
# Simple call dropped at 64.46980897480448
# Simple call dropped at 64.95891583041066
# Simple call dropped at 65.2227966333246
# Simple call dropped at 65.22308657839439
# Simple call dropped at 65.22500305840852
# Simple call dropped at 65.25453131562615
# Simple call dropped at 65.34780839018163
# Complex call dropped at 65.4489462572414
# Simple call dropped at 65.4922787228468
# Complex call dropped at 65.50582031334115
# Simple call dropped at 65.52768640621827
# Simple call dropped at 65.99853043324717
# Simple call dropped at 66.0189443049958
# Complex call dropped at 66.02293586017159
# Complex call dropped at 66.03455578008827
# Simple call dropped at 66.21704183964853
# Simple call dropped at 66.29296670806309
# Simple call dropped at 66.38599709453135
# Complex call dropped at 67.39688728471164
# Complex call dropped at 67.42568278051068
# Simple call dropped at 67.44997142270182
# Simple call dropped at 67.46891502188292
# Complex call dropped at 67.4813238089511
# Simple call dropped at 67.55561954582471
# Simple call dropped at 67.712135340927
# Simple call dropped at 67.7202205109588
# Simple call dropped at 67.82767677623889
# Simple call dropped at 67.84528642613972
# Simple call dropped at 67.87133688850841
# Simple call dropped at 67.96465789061284
# Complex call dropped at 67.99211369648411
# Simple call dropped at 68.04162644539134
# Simple call dropped at 69.60923619281468
# Simple call dropped at 69.89698833506829
# Simple call dropped at 69.93680311894269
# Simple call dropped at 70.11092269302281
# Simple call dropped at 70.25456284958616
# Complex call dropped at 70.5339438321102
# Complex call dropped at 70.54604931837902
# Complex call dropped at 70.55293112146134
# Simple call dropped at 70.72972780081835
# Complex call dropped at 70.92799940612926
# Simple call dropped at 70.9432675123289
# Complex call dropped at 71.02142518085267
# Simple call dropped at 71.02342613263498
# Simple call dropped at 71.10329831135796
# Simple call dropped at 71.15886011795932
# Simple call dropped at 71.25247618663671
# Simple call dropped at 71.55478142028537
# Simple call dropped at 72.02028446139641
# Simple call dropped at 72.06002191506634
# Simple call dropped at 72.94332037058953
# Complex call dropped at 73.65476270578884
# Simple call dropped at 73.6693045476398
# Complex call dropped at 73.9478351142295
# Simple call dropped at 73.95657980544117
# Simple call dropped at 74.39447096045288
# Simple call dropped at 74.40842905546066
# Simple call dropped at 74.69698223374238
# Simple call dropped at 74.92680087384622
# Complex call dropped at 74.92870887019686
# Simple call dropped at 75.3580851885812
# Complex call dropped at 75.36234866339191
# Simple call dropped at 75.39981352688368
# Simple call dropped at 75.40924167315251
# Simple call dropped at 75.47317032256574
# Simple call dropped at 75.5538444818795
# Complex call dropped at 75.5585324816114
# Complex call dropped at 75.63849124058518
# Complex call dropped at 75.72000557277596
# Simple call dropped at 75.90413518789676
# Simple call dropped at 75.93556392628908
# Simple call dropped at 76.38431435811232
# Simple call dropped at 76.4534618768025
# Complex call dropped at 77.50741567051159
# Simple call dropped at 77.55851821336731
# Simple call dropped at 77.56591916917522
# Complex call dropped at 77.7107375590588
# Simple call dropped at 77.7245572772864
# Simple call dropped at 77.72833292420118
# Simple call dropped at 78.33280051578939
# Complex call dropped at 78.35550511349365
# Complex call dropped at 78.38018044469885
# Complex call dropped at 84.09829320895
# Simple call dropped at 84.18068836123493
# Simple call dropped at 84.18614044282295
# Complex call dropped at 84.18699600213482
# Complex call dropped at 84.23613261966999
# Simple call dropped at 84.24984718680071
# Simple call dropped at 84.2696862461741
# Simple call dropped at 84.330088609086
# Complex call dropped at 84.34843121465963
# Simple call dropped at 84.44120615978876
# Simple call dropped at 84.44994683631151
# Complex call dropped at 84.5419708587126
# Complex call dropped at 85.09432438508243
# Simple call dropped at 85.34285566630817
# Complex call dropped at 85.35229197495828
# Simple call dropped at 85.38310563241039
# Simple call dropped at 85.39211071697544
# Simple call dropped at 85.42343844444822
# Complex call dropped at 85.67413108868884
# Simple call dropped at 85.71740055510799
# Simple call dropped at 85.7181097931718
# Simple call dropped at 85.80559978300896
# Simple call dropped at 85.85393278701908
# Simple call dropped at 85.8676108588664
# Simple call dropped at 85.91182211518428
# Simple call dropped at 86.00850269929856
# Complex call dropped at 86.02316733140995
# Simple call dropped at 86.24417082092776
# Simple call dropped at 86.25672294212387
# Simple call dropped at 86.28374805239952
# Simple call dropped at 86.29108225866557
# Complex call dropped at 86.32052790621483
# Simple call dropped at 86.35825595847376
# Simple call dropped at 86.4362106221891
# Complex call dropped at 86.50378998624127
# Simple call dropped at 86.5619985611847
# Simple call dropped at 86.71892899207984
# Complex call dropped at 86.73833396379973
# Simple call dropped at 86.80843987021159
# Complex call dropped at 86.8101407467895
# Simple call dropped at 86.89840799166963
# Simple call dropped at 86.90308420078502
# Complex call dropped at 86.95261594826653
# Simple call dropped at 87.09324466591218
# Simple call dropped at 87.27046721760631
# Complex call dropped at 87.59968862775352
# Simple call dropped at 88.5262615807161
# Simple call dropped at 88.63870962289845
# Complex call dropped at 88.74532158902518
# Simple call dropped at 88.76442921793763
# Complex call dropped at 88.81932865250548
# Complex call dropped at 89.18838968773088
# Simple call dropped at 89.2456939526517
# Simple call dropped at 89.56961213508036
# Simple call dropped at 89.64070464320884
# Complex call dropped at 89.67528897549911
# Complex call dropped at 89.68429637923221
# Simple call dropped at 89.69995085695014
# Simple call dropped at 89.72332115700482
# Simple call dropped at 90.09724574238047
# Complex call dropped at 90.18940564483275
# Complex call dropped at 90.29222307419923
# Simple call dropped at 90.40341370931841
# Complex call dropped at 94.51992331204485
# Simple call dropped at 94.85459348927193
# Complex call dropped at 94.95188453373035
# Simple call dropped at 94.96800277237298
# Simple call dropped at 94.98452164067793
# Simple call dropped at 95.01652274112247
# Simple call dropped at 95.03712323932929
# Complex call dropped at 95.0502137713855
# Simple call dropped at 95.22554867419777
# Simple call dropped at 95.23058016040122
# Complex call dropped at 95.35171487780579
# Complex call dropped at 95.50247796255665
# Simple call dropped at 96.69928267546273
# Complex call dropped at 97.01960412318884
# Complex call dropped at 97.03852283342484
# Simple call dropped at 97.0576145406428
# Simple call dropped at 97.0781925011547
# Complex call dropped at 97.09147834134144
# Complex call dropped at 97.09161508735623
# Simple call dropped at 97.14048372095706
# Simple call dropped at 97.15923169661362
# Simple call dropped at 97.17088377343198
# Simple call dropped at 98.28544512143978
# Complex call dropped at 102.00956883944
# Simple call dropped at 102.05002976430106
# Complex call dropped at 102.06086813504312
# Simple call dropped at 102.41685864855602
# Simple call dropped at 102.99826175590496
# Simple call dropped at 103.22949935117491
# Simple call dropped at 106.3460901080834
# Simple call dropped at 108.62400353387449
# Simple call dropped at 109.118747797776
# Complex call dropped at 111.0875843732485
# Simple call dropped at 111.0975308402075
# Simple call dropped at 111.20107010411058
# Complex call dropped at 111.25307151893426
# Simple call dropped at 111.3095147233548
# Simple call dropped at 111.34386811816665
# Complex call dropped at 111.43452281105684
# Simple call dropped at 112.9615655031991
# Simple call dropped at 112.99073681634403
# Simple call dropped at 112.99408707730252
# Simple call dropped at 113.05124399855727
# Simple call dropped at 113.0706446300822
# Simple call dropped at 116.15588308734237
# Simple call dropped at 116.18315588013257
# Simple call dropped at 116.20415065470488
# Complex call dropped at 116.24341156827923
# Simple call dropped at 116.2900597154959
# Simple call dropped at 116.31238300259125
# Complex call dropped at 116.34667201806069
# Simple call dropped at 116.36359224151494
# Simple call dropped at 116.46250110096551
# Simple call dropped at 116.47303151461931
# Simple call dropped at 116.53035715021579
# Simple call dropped at 116.95818124206278
# Simple call dropped at 117.11645498686781
# Simple call dropped at 117.12654371124758
# Complex call dropped at 117.13888993007298
# Simple call dropped at 117.24523428002831
# Complex call dropped at 117.54328549063588
# Simple call dropped at 117.55472371048904
# Simple call dropped at 117.66126949666041
# Simple call dropped at 117.67069662933655
# Complex call dropped at 118.22569786992159
# Complex call dropped at 120.68925467093472
# Simple call dropped at 120.71517445323546
# Complex call dropped at 120.75680163108326
# Complex call dropped at 120.82675300716171
# Simple call dropped at 120.83696895817994
# Simple call dropped at 120.83970560429826
# Complex call dropped at 121.16116350203816
# Simple call dropped at 121.59095470055385
# Complex call dropped at 121.61736415631542
# Simple call dropped at 121.67170997273257
# Complex call dropped at 122.19932670550563
# Simple call dropped at 122.75975888809957
# Complex call dropped at 122.76005620466407
# Simple call dropped at 122.765643206996
# Simple call dropped at 123.08505706829075
# Simple call dropped at 123.13422291279664
# Simple call dropped at 124.28498797729902
# Simple call dropped at 124.30025428644991
# Simple call dropped at 126.5424431157137
# Simple call dropped at 126.55340282094211
# Simple call dropped at 126.55382303188314
# Complex call dropped at 126.75032801090518
# Simple call dropped at 126.81907367583545
# Simple call dropped at 128.22079816895106
# Simple call dropped at 128.40595442436486
# Complex call dropped at 128.43351074931027
# Complex call dropped at 128.44941949776648
# Complex call dropped at 128.46509830190607
# Complex call dropped at 128.4751977332697
# Simple call dropped at 129.02246577535263
# Simple call dropped at 129.1401059574806
# Simple call dropped at 129.38266744691367
# Simple call dropped at 129.44281977443586
# Simple call dropped at 129.8522635936016
# Simple call dropped at 129.9079912576951
# Simple call dropped at 129.9170475556492
# Simple call dropped at 129.93635148885335
# Complex call dropped at 129.98306059482354
# Complex call dropped at 130.19397254510983
# Simple call dropped at 130.26894869344758
# Complex call dropped at 130.34133924316222
# Simple call dropped at 130.41643897994274
# Simple call dropped at 130.4419053414584
# Simple call dropped at 130.5074078784837
# Simple call dropped at 130.5233227702925
# Simple call dropped at 130.61168764884255
# Simple call dropped at 130.6495707951971
# Complex call dropped at 130.70154643525012
# Simple call dropped at 130.77719852741703
# Simple call dropped at 131.10333484253255
# Complex call dropped at 131.10844689299236
# Complex call dropped at 131.15597580595363
# Simple call dropped at 131.18928122018076
# Complex call dropped at 131.19735743720338
# Simple call dropped at 131.35473624578796
# Simple call dropped at 131.40947352599727
# Complex call dropped at 131.45003315620215
# Simple call dropped at 131.46377765336146
# Simple call dropped at 131.47843083098863
# Complex call dropped at 131.49735591781157
# Complex call dropped at 131.501896274754
# Complex call dropped at 131.51071681782304
# Simple call dropped at 132.13522399750426
# Simple call dropped at 132.46578060225409
# Complex call dropped at 133.3050192166402
# Complex call dropped at 133.32558460850427
# Simple call dropped at 133.37568624524442
# Simple call dropped at 133.74150306320436
# Complex call dropped at 133.82599297374782
# Simple call dropped at 133.83850345753623
# Simple call dropped at 135.18435420487452
# Simple call dropped at 135.20312752863776
# Simple call dropped at 135.29226814077464
# Simple call dropped at 135.2951170681393
# Complex call dropped at 135.3074478844611
# Simple call dropped at 135.37137363054376
# Simple call dropped at 135.39333506527464
# Simple call dropped at 135.40881062779775
# Simple call dropped at 135.41187124467336
# Simple call dropped at 135.4346595112677
# Simple call dropped at 135.43468345402815
# Simple call dropped at 135.44895979179054
# Complex call dropped at 135.4525049619824
# Complex call dropped at 136.97018005905045
# Simple call dropped at 137.90882041842983
# Complex call dropped at 137.94491437128798
# Complex call dropped at 138.00760347012687
# Simple call dropped at 138.09609576526938
# Simple call dropped at 138.19186177152827
# Simple call dropped at 139.55052848404196
# Simple call dropped at 139.65707914316636
# Complex call dropped at 139.6581463569672
# Complex call dropped at 139.6965723442894
# Simple call dropped at 139.7536992570997
# Simple call dropped at 139.87425792227214
# Simple call dropped at 140.13945355482468
# Simple call dropped at 140.41287847124374
# Simple call dropped at 140.42459283058622
# Complex call dropped at 140.4678277200538
# Simple call dropped at 140.83751266602366
# Complex call dropped at 140.84630339511236
# Simple call dropped at 140.94376007083335
# Simple call dropped at 140.97348705223158
# Simple call dropped at 141.0898147431535
# Complex call dropped at 141.27355140793196
# Simple call dropped at 141.33736753057255
# Simple call dropped at 141.34813758048392
# Simple call dropped at 142.026547132606
# Simple call dropped at 142.05830397972719
# Simple call dropped at 142.08700418739824
# Simple call dropped at 142.11294204132798
# Simple call dropped at 142.16199238271756
# Complex call dropped at 142.17238513811319
# Simple call dropped at 142.34445607384825
# Simple call dropped at 142.3464037492207
# Complex call dropped at 142.36951738909917
# Simple call dropped at 142.45483015407368
# Simple call dropped at 142.69211724295243
# Simple call dropped at 142.7415156287111
# Simple call dropped at 142.76688433424798
# Simple call dropped at 142.78094628367342
# Simple call dropped at 142.8695901154317
# Complex call dropped at 143.70827405013748
# Simple call dropped at 143.85427505616536
# Simple call dropped at 143.88442440448117
# Simple call dropped at 143.88443210036942
# Complex call dropped at 143.89901784463572
# Simple call dropped at 144.3985946744514
# Simple call dropped at 144.68118949007055
# Simple call dropped at 144.8387696139767
# Complex call dropped at 144.85002108317002
# Complex call dropped at 144.8902992512004
# Complex call dropped at 144.95868334526787
# Simple call dropped at 144.99882020987906
# Simple call dropped at 145.09792089335795
# Simple call dropped at 145.10216306643872
# Complex call dropped at 145.16129472974902
# Simple call dropped at 145.1659676479993
# Simple call dropped at 145.17495846551057
# Simple call dropped at 145.2010925317209
# Complex call dropped at 145.20243838078062
# Complex call dropped at 145.77566457686592
# Complex call dropped at 145.7904767211582
# Simple call dropped at 145.81369000850387
# Simple call dropped at 145.83147594476048
# Simple call dropped at 145.9849966605797
# Simple call dropped at 145.99583540229972
# Complex call dropped at 146.26985322445853
# Complex call dropped at 146.2766701501942
# Simple call dropped at 146.27789570202674
# Complex call dropped at 146.40021674140957
# Simple call dropped at 146.40073034100007
# Complex call dropped at 146.5474857738675
# Simple call dropped at 147.05996335123427
# Simple call dropped at 147.07522621216296
# Simple call dropped at 147.10215138534977
# Simple call dropped at 147.11277099033893
# Complex call dropped at 147.14745070395432
# Complex call dropped at 147.14924469715754
# Complex call dropped at 147.15782481302662
# Simple call dropped at 147.24248589038098
# Simple call dropped at 147.3349134533889
# Simple call dropped at 147.3427250623302
# Simple call dropped at 147.35702649573193
# Simple call dropped at 147.36501416524155
# Complex call dropped at 147.46383488789505
# Simple call dropped at 148.69604230483924
# Simple call dropped at 148.88075555966324
# Complex call dropped at 148.96718576139878
# Simple call dropped at 148.98713524855648
# Simple call dropped at 149.19788590228407
# Complex call dropped at 149.38677705561435
# Simple call dropped at 149.4129705673251
# Simple call dropped at 149.88394154042737
# Simple call dropped at 150.44139808504133
# Complex call dropped at 150.46646206492096
# Simple call dropped at 150.50461166804686
# Complex call dropped at 150.5084730842092
# Simple call dropped at 150.56685776376648
# Complex call dropped at 150.60510147280536
# Simple call dropped at 150.6821141782976
# Simple call dropped at 150.6914063641904
# Complex call dropped at 150.71239328031157
# Complex call dropped at 150.8010152631945
# Simple call dropped at 151.92208543127
# Complex call dropped at 151.9758112443347
# Simple call dropped at 152.09081644899115
# Complex call dropped at 152.82382441754152
# Simple call dropped at 152.860066997573
# Simple call dropped at 152.88217206829304
# Simple call dropped at 153.74256209647515
# Simple call dropped at 153.78273335454458
# Complex call dropped at 154.11846284712513
# Simple call dropped at 154.1229676014852
# Simple call dropped at 154.1271816345904
# Simple call dropped at 154.2393459819671
# Simple call dropped at 154.2514190133932
# Complex call dropped at 154.28792802818617
# Simple call dropped at 154.33789082659573
# Simple call dropped at 154.41764953417876
# Complex call dropped at 154.42175990844424
# Complex call dropped at 154.5564361565873
# Complex call dropped at 154.57520922399368
# Simple call dropped at 154.8725405365586
# Simple call dropped at 155.70005142674654
# Simple call dropped at 155.70988232629972
# Complex call dropped at 155.7222469802691
# Complex call dropped at 155.7268491493858
# Simple call dropped at 155.75971140576948
# Complex call dropped at 155.77374302406403
# Simple call dropped at 155.82406158923794
# Simple call dropped at 155.87904186714383
# Complex call dropped at 155.87918298284515
# Complex call dropped at 155.9133730968042
# Simple call dropped at 155.98812939514298
# Simple call dropped at 156.0788995084178
# Simple call dropped at 156.08260414837696
# Complex call dropped at 156.08830927915488
# Simple call dropped at 156.09816371248442
# Complex call dropped at 156.16603732592029
# Simple call dropped at 156.49640697779083
# Simple call dropped at 156.53633759558215
# Simple call dropped at 159.26016514907514
# Simple call dropped at 159.47395421331856
# Simple call dropped at 159.59979428531477
# Simple call dropped at 159.60920368336423
# Simple call dropped at 159.62622503061078
# Simple call dropped at 159.77187409080966
# Complex call dropped at 159.77693880019172
# Simple call dropped at 160.07542677408227
# Complex call dropped at 160.10410333937944
# Complex call dropped at 160.1071289624856
# Simple call dropped at 160.75648286258703
# Complex call dropped at 164.04798474937445
# Simple call dropped at 164.0527831627643
# Complex call dropped at 164.07688491148144
# Complex call dropped at 164.14104129859504
# Simple call dropped at 164.1516328742242
# Simple call dropped at 164.2136075350214
# Simple call dropped at 164.3127881075885
# Complex call dropped at 164.31394559879416
# Simple call dropped at 164.51905308104855
# Simple call dropped at 165.4133855372943
# Simple call dropped at 165.41540880108826
# Simple call dropped at 165.49724702232066
# Simple call dropped at 165.50770360676066
# Simple call dropped at 168.21915258584806
# Simple call dropped at 168.2769239027913
# Simple call dropped at 168.29450576921363
# Complex call dropped at 168.3039925029999
# Complex call dropped at 168.56767558814357
# Complex call dropped at 168.59860792807368
# Simple call dropped at 168.86511302371795
# Simple call dropped at 169.16024497897422
# Complex call dropped at 172.49076830750582
# Simple call dropped at 172.5103485718134
# Simple call dropped at 172.63330972779764
# Simple call dropped at 172.67299980376418
# Simple call dropped at 173.7531756631113
# Simple call dropped at 173.94011405533848
# Simple call dropped at 174.04106460877045
# Complex call dropped at 174.0550333678559
# Simple call dropped at 174.08284112287876
# Simple call dropped at 174.12305323391124
# Simple call dropped at 174.16310017212263
# Simple call dropped at 174.21677618201238
# Simple call dropped at 174.2341540432696
# Simple call dropped at 174.2746102753592
# Complex call dropped at 174.38235679516694
# Simple call dropped at 174.48989234262484
# Simple call dropped at 179.63942486223647
# Complex call dropped at 179.63953570856594
# Simple call dropped at 179.66006764046864
# Simple call dropped at 179.6779451544309
# Simple call dropped at 179.67994397502142
# Simple call dropped at 179.68798116133027
# Simple call dropped at 180.03363725266837
# Simple call dropped at 180.8621017518685
# Simple call dropped at 180.86850824098838
# Complex call dropped at 180.8734179465199
# Simple call dropped at 181.04200026126836
# Complex call dropped at 181.20607168813592
# Complex call dropped at 181.34154901256332
# Simple call dropped at 181.3683858965108
# Simple call dropped at 181.4731085389949
# Simple call dropped at 181.4821935017312
# Simple call dropped at 181.48850307519493
# Simple call dropped at 181.62172403281076
# Simple call dropped at 181.70693928156217
# Complex call dropped at 181.82902211784068
# Simple call dropped at 181.93206242325823
# Simple call dropped at 181.95788251393896
# Simple call dropped at 187.3052170348348
# Complex call dropped at 187.30851474545122
# Simple call dropped at 187.40881515810247
# Simple call dropped at 187.7990229869908
# Complex call dropped at 188.21407136022185
# Simple call dropped at 188.22982005927432
# Complex call dropped at 188.28097958300972
# Simple call dropped at 188.47351164589602
# Simple call dropped at 188.72190376398225
# Simple call dropped at 200.7821318757796
# Simple call dropped at 201.0458318736213
# Simple call dropped at 201.05376249314932
# Complex call dropped at 201.07203125356375
# Simple call dropped at 201.245209486602
# Simple call dropped at 201.259794245154
# Simple call dropped at 201.31766231322206
# Simple call dropped at 201.9800990673629
# Simple call dropped at 201.9910949212065
# Simple call dropped at 202.15714901310773
# Simple call dropped at 202.16739771915263
# Simple call dropped at 202.22635680807804
# Simple call dropped at 204.6071634294848
# Simple call dropped at 204.62596019318914
# Simple call dropped at 204.7416554647188
# Simple call dropped at 204.84533396624556
# Complex call dropped at 204.8892475191848
# Simple call dropped at 204.89223664664428
# Simple call dropped at 204.97469196929495
# Simple call dropped at 205.07256421116395
# Simple call dropped at 205.18663181323046
# Complex call dropped at 205.51134399197113
# Simple call dropped at 205.552394115657
# Complex call dropped at 205.6478610747321
# Complex call dropped at 205.85471737188882
# Complex call dropped at 205.9459823027054
# Simple call dropped at 205.99819527637175
# Simple call dropped at 206.0329803666639
# Simple call dropped at 206.04151540434202
# Simple call dropped at 206.07679360682982
# Simple call dropped at 206.11364194426142
# Simple call dropped at 206.17341221347965
# Simple call dropped at 206.2604421659
# Simple call dropped at 206.34090349622878
# Simple call dropped at 206.37121328615336
# Complex call dropped at 206.38989393052094
# Complex call dropped at 206.39387570310865
# Simple call dropped at 206.40553636999223
# Simple call dropped at 206.45702567065348
# Complex call dropped at 206.47281540971005
# Simple call dropped at 206.62289799712656
# Complex call dropped at 206.64070422179532
# Complex call dropped at 206.70272217658567
# Complex call dropped at 206.94084037573472
# Complex call dropped at 207.86207763664098
# Complex call dropped at 208.07292217437418
# Simple call dropped at 208.79869908880212
# Complex call dropped at 208.99935582531228
# Simple call dropped at 209.03595323985326
# Simple call dropped at 209.38531461863445
# Simple call dropped at 209.38699041786478
# Simple call dropped at 209.55058590574268
# Simple call dropped at 209.72611595238055
# Complex call dropped at 209.78514680795996
# Complex call dropped at 209.81544169623453
# Complex call dropped at 209.8391831706545
# Simple call dropped at 209.87899254596505
# Complex call dropped at 210.24288236979976
# Simple call dropped at 210.327645342855
# Simple call dropped at 210.40211432485427
# Simple call dropped at 211.0903209527967
# Simple call dropped at 211.19512295833317
# Simple call dropped at 211.33865735091996
# Simple call dropped at 211.34043230438817
# Complex call dropped at 211.88933709196928
# Simple call dropped at 211.94973304731735
# Complex call dropped at 211.96333791206297
# Complex call dropped at 212.05348954691712
# Complex call dropped at 213.31630516864226
# Simple call dropped at 213.44005302628474
# Simple call dropped at 213.47618993627043
# Simple call dropped at 213.55298948858055
# Complex call dropped at 213.68046285781702
# Simple call dropped at 213.6929010148169
# Simple call dropped at 213.78798136173634
# Simple call dropped at 213.8620148212257
# Simple call dropped at 213.8691657128627
# Simple call dropped at 213.88347941348366
# Complex call dropped at 213.88567979853826
# Simple call dropped at 213.9440149661006
# Simple call dropped at 214.334702033839
# Complex call dropped at 214.5847676980865
# Complex call dropped at 214.62906261695292
# Simple call dropped at 214.6762690305661
# Simple call dropped at 214.6929988276493
# Complex call dropped at 214.7361192148143
# Simple call dropped at 215.3978893515246
# Simple call dropped at 215.4445724224352
# Complex call dropped at 215.4547992675854
# Complex call dropped at 215.47345519495542
# Complex call dropped at 215.49842061910186
# Simple call dropped at 215.76523810444095
# Simple call dropped at 215.775750128302
# Simple call dropped at 215.87993672395933
# Simple call dropped at 215.8975528127972
# Complex call dropped at 215.9759369500097
# Simple call dropped at 216.06255641106765
# Simple call dropped at 216.0908584077409
# Complex call dropped at 217.5212972530165
# Complex call dropped at 217.68529363983885
# Simple call dropped at 217.7465779812895
# Simple call dropped at 217.77170292254016
# Simple call dropped at 217.83009199263506
# Complex call dropped at 217.88731992283408
# Complex call dropped at 217.96366496734882
# Simple call dropped at 218.05208712314806
# Simple call dropped at 218.06482988444742
# Simple call dropped at 218.07518415299185
# Simple call dropped at 218.07894807010072
# Simple call dropped at 218.09034961155965
# Complex call dropped at 218.11484990636572
# Simple call dropped at 218.48927048196157
# Complex call dropped at 218.55006167893973
# Simple call dropped at 218.67525914370503
# Simple call dropped at 218.68892647489088
# Simple call dropped at 218.8487224504442
# Complex call dropped at 218.9253355244998
# Simple call dropped at 218.93799316271392
# Complex call dropped at 218.9575150574011
# Simple call dropped at 218.9597584686208
# Complex call dropped at 218.96481927709917
# Simple call dropped at 218.98487578462797
# Simple call dropped at 219.0326644090257
# Complex call dropped at 219.21795852370172
# Complex call dropped at 221.02872054744748
# Simple call dropped at 221.03264294851888
# Simple call dropped at 221.6763000281164
# Complex call dropped at 222.14547187434997
# Simple call dropped at 222.27475618925388
# Simple call dropped at 222.32101916192002
# Simple call dropped at 222.32445903208918
# Simple call dropped at 222.35930591983134
# Complex call dropped at 222.5473637535245
# Simple call dropped at 222.57809258166074
# Simple call dropped at 222.82630502154294
# Simple call dropped at 222.83038042644827
# Simple call dropped at 222.83701540090985
# Simple call dropped at 222.84086067749303
# Simple call dropped at 222.85862131081606
# Simple call dropped at 222.9801908565608
# Simple call dropped at 223.08012555334085
# Simple call dropped at 223.1538599187763
# Simple call dropped at 223.23533175143137
# Simple call dropped at 223.26099725104942
# Complex call dropped at 223.41382210767816
# Simple call dropped at 223.5539311581204
# Simple call dropped at 223.61762922844582
# Simple call dropped at 223.61811791433098
# Simple call dropped at 223.62845672880587
# Simple call dropped at 223.64415860809882
# Simple call dropped at 223.89015064521155
# Complex call dropped at 224.4513505799551
# Simple call dropped at 225.57888246256414
# Complex call dropped at 227.16989643087476
# Simple call dropped at 227.17996147104301
# Simple call dropped at 227.18882523434903
# Simple call dropped at 227.2572439393677
# Simple call dropped at 227.2587686867808
# Complex call dropped at 227.39058885851153
# Simple call dropped at 227.43608894345124
# Simple call dropped at 228.08712052511737
# Simple call dropped at 228.09644790415723
# Simple call dropped at 228.1750377107883
# Simple call dropped at 229.06528329238245
# Complex call dropped at 229.1823324324262
# Simple call dropped at 229.20356903325995
# Complex call dropped at 229.78236253810826
# Simple call dropped at 230.0454783470438
# Simple call dropped at 230.7002783831856
# Simple call dropped at 230.77338076184702
# Simple call dropped at 230.77652000301322
# Simple call dropped at 230.95867573724607
# Complex call dropped at 230.96689045249573
# Simple call dropped at 231.04008157774518
# Simple call dropped at 231.0424388754661
# Complex call dropped at 231.1142416739546
# Simple call dropped at 231.17515340882537
# Simple call dropped at 231.19817018121458
# Simple call dropped at 231.32216340594363
# Complex call dropped at 231.32955593974296
# Simple call dropped at 231.36106132557902
# Simple call dropped at 231.3975353903605
# Simple call dropped at 231.40161119768518
# Simple call dropped at 231.4893258378261
# Complex call dropped at 231.52678569899123
# Simple call dropped at 231.74808040496077
# Complex call dropped at 231.81425743313966
# Simple call dropped at 231.93537360967994
# Simple call dropped at 231.99887730306097
# Complex call dropped at 232.01189232002739
# Simple call dropped at 232.2730876555283
# Simple call dropped at 232.34585074896637
# Simple call dropped at 232.73406709235866
# Complex call dropped at 232.80712627259658
# Simple call dropped at 232.9682443179857
# Complex call dropped at 232.972793170744
# Complex call dropped at 233.00050429803125
# Simple call dropped at 233.0717317948199
# Simple call dropped at 233.40716087798413
# Simple call dropped at 233.6545511603694
# Complex call dropped at 233.85090782673973
# Simple call dropped at 233.86201096841774
# Simple call dropped at 234.10341211933178
# Simple call dropped at 234.29553396160466
# Complex call dropped at 234.32185582928284
# Simple call dropped at 234.40162440404822
# Simple call dropped at 234.52123104710083
# Simple call dropped at 234.57104009956993
# Simple call dropped at 234.65350003166807
# Simple call dropped at 234.69741694719684
# Simple call dropped at 234.71950334727023
# Simple call dropped at 234.76143530130236
# Simple call dropped at 234.82632638290363
# Complex call dropped at 234.85000170166816
# Complex call dropped at 235.29153518172828
# Simple call dropped at 235.42308067691977
# Complex call dropped at 235.54818886319032
# Simple call dropped at 235.57172152881998
# Simple call dropped at 235.58921948493355
# Simple call dropped at 236.06219862388804
# Complex call dropped at 236.22792751168996
# Complex call dropped at 236.45477389483958
# Simple call dropped at 236.55824249390807
# Simple call dropped at 243.90501343351292
# Simple call dropped at 243.94336176946695
# Simple call dropped at 243.94403799258905
# Simple call dropped at 244.017617364303
# Complex call dropped at 244.02749152484822
# Simple call dropped at 244.12226337447893
# Simple call dropped at 244.14038161453024
# Simple call dropped at 244.15901565942676
# Complex call dropped at 244.3880656344557
# Simple call dropped at 244.39312301825547
# Complex call dropped at 244.60850546058433
# Simple call dropped at 244.67729146633732
# Simple call dropped at 244.69204741194127
# Complex call dropped at 244.71700150037748
# Simple call dropped at 244.74252155710676
# Simple call dropped at 244.7461138983662
# Simple call dropped at 244.7667555616001
# Simple call dropped at 244.76706422187686
# Simple call dropped at 244.788093156738
# Simple call dropped at 244.8099032138105
# Complex call dropped at 247.79738057200157
# Simple call dropped at 248.35019252768916
# Complex call dropped at 249.0655435554512
# Simple call dropped at 249.07283626094812
# Simple call dropped at 249.07608904189055
# Complex call dropped at 249.08034794265157
# Simple call dropped at 249.09471628112763
# Simple call dropped at 249.1279950984693
# Simple call dropped at 249.22387479096224
# Simple call dropped at 249.76831716382188
# Complex call dropped at 249.81430499079588
# Complex call dropped at 250.48190295294518
# Complex call dropped at 250.77548291293922
# Simple call dropped at 250.7772247060109
# Complex call dropped at 250.88413453491864
# Simple call dropped at 251.00131651023207
# Simple call dropped at 251.12954841635695
# Complex call dropped at 251.15194577612286
# Simple call dropped at 251.21236658822303
# Complex call dropped at 251.33671097931008
# Complex call dropped at 251.3823936162423
# Complex call dropped at 251.52319598550153
# Complex call dropped at 251.54619699519077
# Simple call dropped at 251.61709529003622
# Simple call dropped at 251.76063116829155
# Simple call dropped at 251.76663313237154
# Complex call dropped at 251.91646510592986
# Complex call dropped at 251.92829904296082
# Simple call dropped at 252.08544844656615
# Complex call dropped at 252.10864808790495
# Complex call dropped at 252.1228963797419
# Simple call dropped at 252.16104204827292
# Simple call dropped at 252.18023080708235
# Simple call dropped at 252.2810579178218
# Simple call dropped at 252.52820534312363
# Simple call dropped at 252.66521365521015
# Complex call dropped at 252.74354547013348
# Simple call dropped at 252.86615638980328
# Simple call dropped at 253.02892907720621
# Simple call dropped at 253.10800602019683
# Complex call dropped at 253.16633449712796
# Simple call dropped at 253.20842506134557
# Simple call dropped at 254.11552946847692
# Complex call dropped at 254.13799297100155
# Complex call dropped at 254.31487770953134
# Complex call dropped at 254.3371142091936
# Simple call dropped at 254.52205076528446
# Simple call dropped at 254.57921096320482
# Simple call dropped at 254.63799017007386
# Complex call dropped at 254.6432648503321
# Simple call dropped at 254.90921776880535
# Complex call dropped at 254.92031274677583
# Simple call dropped at 255.56592759741457
# Complex call dropped at 255.65286353835907
# Simple call dropped at 256.05156004219435
# Complex call dropped at 256.0695570040412
# Simple call dropped at 256.0971960965093
# Simple call dropped at 256.50431506221105
# Simple call dropped at 256.51963023619385
# Simple call dropped at 256.53486176679377
# Simple call dropped at 256.6301692069201
# Simple call dropped at 256.64950941770473
# Simple call dropped at 256.71452917413876
# Complex call dropped at 262.7632820402993
# Simple call dropped at 262.81298579671227
# Complex call dropped at 263.2234517106625
# Complex call dropped at 263.24206640394254
# Simple call dropped at 263.40528884666963
# Simple call dropped at 263.4359817081632
# Simple call dropped at 264.02789624069175
# Simple call dropped at 264.03296233069267
# Simple call dropped at 264.0497777495527
# Complex call dropped at 264.13933516322464
# Simple call dropped at 264.16841457614584
# Complex call dropped at 264.19938110073025
# Simple call dropped at 264.3773523665079
# Simple call dropped at 264.4062608881919
# Simple call dropped at 264.4457924587597
# Simple call dropped at 264.47279389272023
# Simple call dropped at 264.5707048793001
# Simple call dropped at 264.5759548740266
# Simple call dropped at 265.60229003290686
# Simple call dropped at 265.6356949174734
# Simple call dropped at 265.64449138452477
# Simple call dropped at 265.695366157564
# Simple call dropped at 266.11994072160013
# Complex call dropped at 266.24219665295095
# Simple call dropped at 267.82491674785115
# Simple call dropped at 267.8788201398295
# Simple call dropped at 269.36067004703136
# Simple call dropped at 269.520152601766
# Simple call dropped at 270.7452597432727
# Simple call dropped at 270.7649679676596
# Simple call dropped at 270.97534785916343
# Simple call dropped at 271.0167865619585
# Simple call dropped at 271.4295999799128
# Complex call dropped at 271.4735022607099
# Complex call dropped at 271.8669822119307
# Complex call dropped at 272.3149654736484
# Complex call dropped at 272.99979408140695
# Simple call dropped at 273.23129318030226
# Simple call dropped at 274.0584603002552
# Complex call dropped at 274.0642545000028
# Complex call dropped at 274.40230400389305
# Simple call dropped at 274.4888114043482
# Complex call dropped at 274.53470793637376
# Complex call dropped at 274.5556559124925
# Simple call dropped at 274.55941849537743
# Complex call dropped at 274.5687767011066
# Complex call dropped at 274.88594522491775
# Simple call dropped at 274.9677478017797
# Simple call dropped at 275.0397622698092
# Simple call dropped at 275.24906478058216
# Simple call dropped at 275.26559601315904
# Complex call dropped at 275.33224553027816
# Simple call dropped at 275.33301734257475
# Simple call dropped at 275.3439590046563
# Simple call dropped at 275.35545084316476
# Simple call dropped at 275.3746976270425
# Simple call dropped at 275.3893472282176
# Simple call dropped at 275.4582363873323
# Simple call dropped at 275.67593258922415
# Simple call dropped at 275.74144922601903
# Complex call dropped at 275.74501965685477
# Simple call dropped at 275.787282723676
# Simple call dropped at 275.7872898543409
# Simple call dropped at 275.81708422288204
# Simple call dropped at 276.06064701618465
# Simple call dropped at 276.12171448121063
# Complex call dropped at 276.3259366596704
# Simple call dropped at 276.4196539384907
# Complex call dropped at 277.0850468193467
# Simple call dropped at 277.09066588293445
# Simple call dropped at 277.7177588062835
# Simple call dropped at 277.76568024879043
# Simple call dropped at 277.766506273586
# Simple call dropped at 277.8059612038878
# Complex call dropped at 277.84193470717855
# Complex call dropped at 277.93710117627677
# Complex call dropped at 277.9592880983557
# Simple call dropped at 278.32221577954454
# Simple call dropped at 278.4226734804456
# Simple call dropped at 278.5897931137315
# Simple call dropped at 278.7788649950564
# Complex call dropped at 278.8494642443132
# Simple call dropped at 278.8915379223955
# Simple call dropped at 278.9547552574659
# Simple call dropped at 279.08399131272733
# Simple call dropped at 279.0953642612794
# Simple call dropped at 279.0961594993952
# Simple call dropped at 279.1562139039773
# Simple call dropped at 279.1702972556507
# Simple call dropped at 279.7039312327558
# Simple call dropped at 279.9119319266905
# Simple call dropped at 280.2134544230619
# Simple call dropped at 280.2183815471057
# Complex call dropped at 280.2457448040004
# Simple call dropped at 280.33173768729915
# Simple call dropped at 280.38831681334136
# Complex call dropped at 280.40730373014503
# Simple call dropped at 280.56117336230477
# Simple call dropped at 280.7768017088397
# Simple call dropped at 281.4069827138599
# Simple call dropped at 282.2979658015554
# Simple call dropped at 282.33768053578234
# Simple call dropped at 282.3766189783762
# Simple call dropped at 282.38663344409287
# Simple call dropped at 283.2506660354677
# Complex call dropped at 283.26799646954777
# Complex call dropped at 283.301829462788
# Simple call dropped at 283.3063563002381
# Simple call dropped at 283.32771517131124
# Simple call dropped at 283.36964184612617
# Simple call dropped at 283.4160393027421
# Complex call dropped at 283.6382386903211
# Simple call dropped at 283.8860658374659
# Complex call dropped at 284.1450065851307
# Simple call dropped at 284.2466886763256
# Complex call dropped at 284.3828629209549
# Complex call dropped at 284.406109644683
# Complex call dropped at 284.4289404769007
# Complex call dropped at 284.43321630093016
# Complex call dropped at 284.46702835378363
# Simple call dropped at 284.58249166514634
# Complex call dropped at 284.60475100812323
# Simple call dropped at 286.0669632200295
# Simple call dropped at 286.10299324791333
# Complex call dropped at 286.1326873409859
# Simple call dropped at 286.14811094213235
# Simple call dropped at 286.15217130715286
# Simple call dropped at 286.27829514540963
# Simple call dropped at 286.2953260512202
# Simple call dropped at 286.95324924482964
# Complex call dropped at 286.958428042955
# Simple call dropped at 286.99363161508495
# Simple call dropped at 287.0052832950937
# Complex call dropped at 287.41041111580574
# Simple call dropped at 287.44091995360515
# Complex call dropped at 287.5685979709361
# Complex call dropped at 287.6137270859241
# Complex call dropped at 288.5110199587899
# Complex call dropped at 288.82737515028504
# Complex call dropped at 288.86356402420745
# Complex call dropped at 289.141405978695
# Complex call dropped at 289.1820904240503
# Simple call dropped at 289.3506974985974
# Simple call dropped at 289.46339529520674
# Simple call dropped at 289.49352517208985
# Complex call dropped at 289.49483699808013
# Simple call dropped at 289.51426622555766
# Simple call dropped at 289.8648378177259
# Simple call dropped at 289.90041163013854
# Complex call dropped at 289.9642704679264
# Simple call dropped at 289.9778510871185
# Simple call dropped at 290.04425925729976
# Complex call dropped at 290.2971428492163
# Simple call dropped at 290.59370236196185
# Simple call dropped at 290.76017729240823
# Simple call dropped at 290.9969172504744
# Complex call dropped at 291.01451788086837
# Simple call dropped at 291.023005531539
# Simple call dropped at 291.1745095423471
# Complex call dropped at 291.18881185333674
# Simple call dropped at 291.19647663563364
# Simple call dropped at 291.24299781120123
# Simple call dropped at 291.25968934699216
# Simple call dropped at 291.2767394761542
# Simple call dropped at 291.4419942113238
# Complex call dropped at 291.44794624657226
# Simple call dropped at 291.45943708770386
# Simple call dropped at 291.5683878558375
# Complex call dropped at 292.59738301577545
# Complex call dropped at 292.6789171774252
# Simple call dropped at 292.7038121571566
# Complex call dropped at 292.7493224707496
# Simple call dropped at 292.763520710563
# Simple call dropped at 292.7762672873225
# Complex call dropped at 293.98434445276706
# Complex call dropped at 294.20112764407537
# Complex call dropped at 297.8327960022503
# ...
# Simple call dropped at 602.938627149683
# Simple call dropped at 603.7784726171905
# Simple call dropped at 603.8100236133238
# Complex call dropped at 604.0496101664676
# Simple call dropped at 604.2578307012943
# Simple call dropped at 604.2602868257075
# Simple call dropped at 604.2866101792423
# Complex call dropped at 604.3956713678731
# Simple call dropped at 610.3422788877136
# Simple call dropped at 610.6123702848372
# Simple call dropped at 610.6314631798642
# Simple call dropped at 610.6408910258444
# Complex call dropped at 610.6887868648645
# Simple call dropped at 610.7295031413627
# Simple call dropped at 610.7329438284523
# Simple call dropped at 610.7594683580942
# Simple call dropped at 610.8231765749615
# Simple call dropped at 610.9818225420477
# Complex call dropped at 611.0086119196425
# Complex call dropped at 611.0260959484258
# Simple call dropped at 612.7428230023078
# Simple call dropped at 612.7707000925365
# Complex call dropped at 612.782165602808
# Simple call dropped at 612.8595095822203
# Complex call dropped at 612.9339792174727
# Simple call dropped at 613.0394824178435
# Complex call dropped at 613.6094561172245
# Complex call dropped at 613.8506325703196
# Simple call dropped at 613.9425845529429
# Simple call dropped at 613.96049432102
# Simple call dropped at 614.0025135044019
# Simple call dropped at 614.2238953528562
# Simple call dropped at 614.2472348095373
# Simple call dropped at 614.4131519548146
# Simple call dropped at 614.4278640264721
# Simple call dropped at 614.4885805447058
# Complex call dropped at 614.5622846408843
# Complex call dropped at 615.3335384385955
# Complex call dropped at 615.3791311270232
# Simple call dropped at 615.4343568982378
# Simple call dropped at 615.4779752039587
# Simple call dropped at 615.6764884601341
# Simple call dropped at 616.0373674769368
# Simple call dropped at 617.2060130463659
# Simple call dropped at 617.3023974105331
# Simple call dropped at 617.3121712256213
# Complex call dropped at 618.5847213423417
# Simple call dropped at 618.6196725116642
# Simple call dropped at 622.3548654228908
# Simple call dropped at 622.5642397158659
# Simple call dropped at 622.5943224626754
# Simple call dropped at 623.0589309622665
# Simple call dropped at 623.0716705819929
# Simple call dropped at 623.3552128425741
# Simple call dropped at 623.4013964531832
# Simple call dropped at 623.4343763557451
# Complex call dropped at 623.4913347596898
# Simple call dropped at 623.5126278625829
# Complex call dropped at 623.5719638853319
# Simple call dropped at 623.7213337408748
# Simple call dropped at 623.8391383653184
# Complex call dropped at 624.8686315872245
# Simple call dropped at 624.9772727612456
# Simple call dropped at 625.0127244673802
# Complex call dropped at 625.0222366434234
# Simple call dropped at 625.0449838078374
# Simple call dropped at 625.2379338590654
# Complex call dropped at 625.2470883758455
# Simple call dropped at 625.3167738621206
# Simple call dropped at 625.8015274683398
# Simple call dropped at 625.8142071701786
# Complex call dropped at 625.818870793512
# Simple call dropped at 626.2055492629776
# Simple call dropped at 626.2260168134253
# Complex call dropped at 626.5146873654821
# Simple call dropped at 626.7125944650363
# Simple call dropped at 626.7663254673201
# Simple call dropped at 626.7671329230952
# Complex call dropped at 627.473863616531
# Complex call dropped at 628.1629861923321
# Complex call dropped at 628.3503008852463
# Simple call dropped at 628.4015880448289
# Simple call dropped at 628.7864600721417
# Simple call dropped at 628.9791325734129
# Simple call dropped at 629.0519894785783
# Complex call dropped at 629.2003379428451
# Simple call dropped at 629.7295336257569
# Simple call dropped at 629.9191096098272
# Simple call dropped at 630.0620102590028
# Simple call dropped at 630.0916427116384
# Simple call dropped at 632.5182365397782
# Complex call dropped at 633.5307951474422
# Complex call dropped at 636.9253206872601
# Simple call dropped at 637.1089516349355
# Complex call dropped at 637.4241732938189
# Simple call dropped at 638.0219866079325
# Simple call dropped at 638.2899258403103
# Simple call dropped at 638.4080089011889
# Complex call dropped at 638.4427119547254
# Complex call dropped at 640.6205538255668
# Simple call dropped at 640.6531814572995
# Simple call dropped at 640.6661534360118
# Complex call dropped at 640.6914741904566
# Simple call dropped at 640.6946488387432
# Complex call dropped at 640.7530551543812
# Simple call dropped at 641.0350580207436
# Complex call dropped at 641.1486467182776
# Simple call dropped at 641.1744779739515
# Simple call dropped at 641.1899888960368
# Simple call dropped at 641.4959834690305
# Simple call dropped at 641.566555206448
# Simple call dropped at 641.5847964510143
# Complex call dropped at 641.6880912670453
# Complex call dropped at 641.8632133634136
# Complex call dropped at 644.5061713165138
# Simple call dropped at 644.5142674190893
# Simple call dropped at 644.5881931403518
# Complex call dropped at 645.5485831676808
# Simple call dropped at 645.5959112325895
# Complex call dropped at 645.7859942499138
# Complex call dropped at 645.7926082156769
# Complex call dropped at 645.8895478696314
# Simple call dropped at 645.9081966745944
# Simple call dropped at 645.9119126485846
# Simple call dropped at 645.9549918888047
# Complex call dropped at 646.0045080968778
# Simple call dropped at 646.0662847223086
# Simple call dropped at 646.2919013810642
# Complex call dropped at 646.2933701748372
# Simple call dropped at 646.7421539791876
# Simple call dropped at 646.8465888725212
# Simple call dropped at 646.847403536941
# Complex call dropped at 646.8641738577528
# Simple call dropped at 646.9798502886282
# Simple call dropped at 646.9810712578233
# Complex call dropped at 646.9994979486733
# Complex call dropped at 646.9997961895044
# Complex call dropped at 647.0464696477641
# Complex call dropped at 647.0955996357081
# Simple call dropped at 647.2182313207186
# Simple call dropped at 647.2410213477199
# Simple call dropped at 647.250847737299
# Simple call dropped at 647.2512511496997
# Simple call dropped at 649.5659420198572
# Complex call dropped at 649.592573250309
# Complex call dropped at 649.6525614047907
# Simple call dropped at 652.0365544272173
# Simple call dropped at 652.0523728654846
# Simple call dropped at 652.0571207011138
# Complex call dropped at 652.0801339900756
# Complex call dropped at 652.0848965743644
# Complex call dropped at 652.1027181353378
# Simple call dropped at 652.1034495328687
# Simple call dropped at 652.1650263858913
# Simple call dropped at 652.2161104104869
# Simple call dropped at 652.218616443129
# Complex call dropped at 652.2676235019762
# Simple call dropped at 652.3257169080676
# Simple call dropped at 652.3418268289566
# Simple call dropped at 653.2744810461446
# Simple call dropped at 653.322770390409
# Complex call dropped at 653.4646840024349
# Simple call dropped at 653.6884458042898
# Simple call dropped at 653.6905687177831
# Simple call dropped at 653.772221382099
# Complex call dropped at 653.8135265043072
# Simple call dropped at 653.8489671882746
# Simple call dropped at 653.9586633710638
# Simple call dropped at 654.0830440579446
# Complex call dropped at 654.0856687392943
# Simple call dropped at 654.1393473421751
# Simple call dropped at 654.1547821806321
# Simple call dropped at 654.7206862861468
# Complex call dropped at 655.5786319994685
# Simple call dropped at 655.5835972031645
# Simple call dropped at 655.6414592857362
# Simple call dropped at 655.7096058932403
# Complex call dropped at 655.7214080832775
# Simple call dropped at 655.7319611559811
# Simple call dropped at 663.672095199134
# Complex call dropped at 663.890474263373
# Complex call dropped at 663.9984322251998
# Complex call dropped at 664.0903006649803
# Simple call dropped at 664.3108711765905
# Complex call dropped at 665.389467083916
# Simple call dropped at 665.452260929375
# Complex call dropped at 665.7306831154855
# Complex call dropped at 665.8449156436343
# Simple call dropped at 668.1083966206032
# Simple call dropped at 668.2596983873599
# Simple call dropped at 668.2951944929889
# Simple call dropped at 668.2973384495608
# Complex call dropped at 668.3326422295688
# Simple call dropped at 668.359344688167
# Simple call dropped at 668.4825465356655
# Simple call dropped at 668.8168163060012
# Simple call dropped at 668.8491596355191
# Simple call dropped at 668.9568087295559
# Complex call dropped at 669.0177464418856
# Complex call dropped at 669.1563004735947
# Simple call dropped at 669.1592784990754
# Simple call dropped at 669.1659533618797
# Simple call dropped at 669.3998128911592
# Simple call dropped at 669.4049369381397
# Simple call dropped at 669.4210754447556
# Complex call dropped at 669.9072623497526
# Simple call dropped at 669.9424509355821
# Complex call dropped at 669.9431790137938
# Simple call dropped at 670.0684155684006
# Complex call dropped at 670.0705093028429
# Simple call dropped at 670.0968332928446
# Simple call dropped at 670.1399802506022
# Simple call dropped at 671.2095663907838
# Simple call dropped at 671.4412956751371
# Simple call dropped at 671.5376272935175
# Simple call dropped at 673.1205208347485
# Simple call dropped at 673.1540343430418
# Simple call dropped at 673.2368203355102
# Simple call dropped at 673.458042152342
# Simple call dropped at 673.5649559317887
# Complex call dropped at 673.5700038340002
# Simple call dropped at 673.623667836389
# Simple call dropped at 673.6535519310918
# Simple call dropped at 673.6537846906325
# Simple call dropped at 673.7687059715449
# Complex call dropped at 674.380250215885
# Simple call dropped at 674.464941799867
# Simple call dropped at 674.6431134850592
# Simple call dropped at 674.6657857161496
# Simple call dropped at 674.6685454486108
# Simple call dropped at 674.6935304085256
# Complex call dropped at 675.3226422890347
# Simple call dropped at 675.8420327195857
# Simple call dropped at 676.5967605820672
# Complex call dropped at 676.7279981642369
# Complex call dropped at 676.7530891310788
# Complex call dropped at 676.8086953859761
# Simple call dropped at 676.84873529513
# Simple call dropped at 676.8671316533379
# Complex call dropped at 676.9458951335562
# Simple call dropped at 677.0008993738104
# Simple call dropped at 677.2999642197643
# Simple call dropped at 677.3419135543684
# Complex call dropped at 677.3842058945087
# Complex call dropped at 677.4370300304288
# Simple call dropped at 677.9761601224662
# Simple call dropped at 678.2535526908142
# Simple call dropped at 678.2854214540388
# Simple call dropped at 678.3117508131161
# Simple call dropped at 678.4496457662323
# Simple call dropped at 678.6030492526718
# Complex call dropped at 678.691121081734
# Complex call dropped at 678.8695484989015
# Simple call dropped at 678.9990715080578
# Simple call dropped at 679.1323188391721
# Complex call dropped at 680.5037398588158
# Complex call dropped at 680.5073705067542
# Complex call dropped at 680.6491914236733
# Simple call dropped at 680.6574654488038
# Simple call dropped at 680.677819429872
# Simple call dropped at 680.8040495828487
# Simple call dropped at 680.8110119190408
# Simple call dropped at 680.8988553450063
# Simple call dropped at 680.9157562042259
# Simple call dropped at 681.0152041370317
# Complex call dropped at 681.3487776477912
# Simple call dropped at 681.35789438884
# Simple call dropped at 681.5430665646685
# Complex call dropped at 681.6909892675893
# Simple call dropped at 681.7859340951587
# Simple call dropped at 681.9385634602413
# Simple call dropped at 682.5916750016778
# Simple call dropped at 682.5921588221526
# Simple call dropped at 682.5961510145783
# Complex call dropped at 682.6219933001171
# Simple call dropped at 684.3488785333254
# Simple call dropped at 684.3943045491067
# Complex call dropped at 684.5605558874992
# Complex call dropped at 684.5669874144135
# Simple call dropped at 684.6033223109871
# Simple call dropped at 684.622800206
# Complex call dropped at 692.5216254995386
# Simple call dropped at 692.5311434273292
# Simple call dropped at 692.6362807631797
# Simple call dropped at 694.6370853160053
# Complex call dropped at 694.7183147250531
# Simple call dropped at 694.845392514439
# Simple call dropped at 694.857330619101
# Simple call dropped at 694.8587376883042
# Complex call dropped at 695.1678323426244
# Simple call dropped at 695.7598171838521
# Complex call dropped at 695.8157649890026
# Simple call dropped at 695.8501908832136
# Simple call dropped at 695.9187315937409
# Simple call dropped at 696.2226817162303
# Complex call dropped at 696.2964541928508
# Simple call dropped at 696.3639142998425
# Simple call dropped at 696.3878795383065
# Simple call dropped at 696.427276494739
# Simple call dropped at 696.58579119242
# Simple call dropped at 696.5976801436738
# Complex call dropped at 696.6096065063263
# Simple call dropped at 696.7183095958644
# Simple call dropped at 696.7218877121447
# Simple call dropped at 696.7584116816663
# Complex call dropped at 696.8436533806326
# Simple call dropped at 696.8582998177653
# Simple call dropped at 696.979682126872
# Simple call dropped at 697.555465609759
# Complex call dropped at 697.5976470228694
# Complex call dropped at 697.7035515126547
# Complex call dropped at 697.7560378477631
# Complex call dropped at 697.7638775877994
# Simple call dropped at 697.9727129704916
# Simple call dropped at 698.0460644047486
# Simple call dropped at 698.0576071259821
# Simple call dropped at 698.1301923771308
# Complex call dropped at 698.1658658165721
# Complex call dropped at 698.2984289383526
# Simple call dropped at 698.3862930279255
# Simple call dropped at 698.411000007149
# Simple call dropped at 700.1857950215311
# Complex call dropped at 700.215886887274
# Complex call dropped at 700.2842702958333
# Complex call dropped at 700.294459565379
# Complex call dropped at 702.7610683331097
# Simple call dropped at 702.7744057911559
# Simple call dropped at 702.8451000082556
# Complex call dropped at 702.9104590690546
# Complex call dropped at 702.9436546848847
# Complex call dropped at 703.2328476614911
# Simple call dropped at 703.2494001586409
# Simple call dropped at 703.4072572205615
# Simple call dropped at 703.4078197452056
# Simple call dropped at 703.4315612205968
# Complex call dropped at 703.5278675493627
# Complex call dropped at 704.6737964159805
# Simple call dropped at 704.7995789593731
# Simple call dropped at 704.9797092064567
# Simple call dropped at 705.1882102782185
# Simple call dropped at 707.6147990780785
# Simple call dropped at 707.7322408871424
# Simple call dropped at 707.7512249721477
# Simple call dropped at 707.773736924668
# Simple call dropped at 708.9280201844088
# Simple call dropped at 708.9465834195939
# Complex call dropped at 708.9473625329183
# Complex call dropped at 708.9787539915133
# Simple call dropped at 709.365874534874
# Simple call dropped at 709.4199539033324
# Simple call dropped at 709.4464813503695
# Simple call dropped at 715.2055364087078
# Simple call dropped at 715.2310624150796
# Simple call dropped at 715.32359064101
# Simple call dropped at 715.3749404224823
# Complex call dropped at 715.4489604731788
# Simple call dropped at 715.4580402220064
# Complex call dropped at 715.5046091275663
# Simple call dropped at 715.5722721733855
# Simple call dropped at 715.6258175856043
# Complex call dropped at 715.6907678557886
# Complex call dropped at 715.6919672794401
# Simple call dropped at 715.7501707205017
# Complex call dropped at 716.1740648342591
# Simple call dropped at 716.2228416198478
# Complex call dropped at 716.4620769267003
# Simple call dropped at 716.510156709186
# Complex call dropped at 716.6422289783507
# Simple call dropped at 716.6844321911665
# Complex call dropped at 717.046412479853
# Simple call dropped at 717.0842478274412
# Simple call dropped at 717.1131810502205
# Simple call dropped at 717.1330800132237
# Simple call dropped at 717.1624373513628
# Complex call dropped at 717.1916563747017
# Simple call dropped at 717.2522996626506
# Simple call dropped at 717.3143839681034
# Complex call dropped at 717.3772531195211
# Complex call dropped at 717.3790799961449
# Complex call dropped at 717.6295627435692
# Simple call dropped at 717.6593901133866
# Complex call dropped at 717.728095724168
# Simple call dropped at 717.8646575058532
# Simple call dropped at 717.957181525966
# Simple call dropped at 718.1059987659518
# Simple call dropped at 718.7038831887736
# Simple call dropped at 718.746233632763
# Complex call dropped at 719.9975428929553

# %%
def metrics_df(results_a, results_b):
    """Create a metrics comparison DataFrame for two sets of results."""
    df = pd.DataFrame({
        'Metric': ['Average Waiting Time', 'Average Service Time', 'Average Total Time',
                    'Average Waiting Time Simple', 'Average Waiting Time Complex',
                    'Average Waiting Time Queue 1', 'Average Waiting Time Queue 2',
                'Average Queue Length 1', 'Average Queue Length 2'],
        'Optimal Policy': [results_a['avg_waiting_time'], results_a['avg_service_time'], results_a['avg_total_time'],
                           results_a['avg_waiting_by_type']['Simple'], results_a['avg_waiting_by_type']['Complex'],
                           results_a['avg_waiting_by_queue'][1], results_a['avg_waiting_by_queue'][2],
                        results_a['avg_queue_length'][0], results_a['avg_queue_length'][1]],
        'Generated Policy': [results_b['avg_waiting_time'], results_b['avg_service_time'], results_b['avg_total_time'],
                           results_b['avg_waiting_by_type']['Simple'], results_b['avg_waiting_by_type']['Complex'],
                           results_b['avg_waiting_by_queue'][1], results_b['avg_waiting_by_queue'][2],
                    results_b['avg_queue_length'][0], results_b['avg_queue_length'][1]]
    })
    df.set_index('Metric', inplace=True)
    df['Delta'] = df['Optimal Policy'] - df['Generated Policy']
    
    return df

# %%
# Compare metrics between the two policies with different runtimes
day_df = metrics_df(results, results_2)
week_df = metrics_df(results_week, results_week_2)
month_df = metrics_df(results_month, results_month_2)

# Display the comparison
print("\nComparison of Metrics Between Policies (One Day):")
print(day_df)
print("\nComparison of Metrics Between Policies (One Week):")
print(week_df)
print("\nComparison of Metrics Between Policies (One Month):")
print(month_df)
# Out:
# Comparison of Metrics Between Policies (One Day):
#                               Optimal Policy  Generated Policy     Delta
# Metric
# Average Waiting Time                0.898389          1.375524 -0.477134
# Average Service Time                0.128436          0.136215 -0.007779
# Average Total Time                  1.026826          1.511739 -0.484913
# Average Waiting Time Simple         0.789464          1.315505 -0.526042
# Average Waiting Time Complex        1.177240          1.527407 -0.350167
# Average Waiting Time Queue 1        0.669655          1.237272 -0.567617
# Average Waiting Time Queue 2        1.286545          1.560482 -0.273938
# Average Queue Length 1              7.812500         11.483333 -3.670833
# Average Queue Length 2              8.387500         11.487500 -3.100000
#
# Comparison of Metrics Between Policies (One Week):
#                               Optimal Policy  Generated Policy     Delta
# Metric
# Average Waiting Time                1.617071          2.419597 -0.802525
# Average Service Time                0.130407          0.151184 -0.020778
# Average Total Time                  1.747478          2.570781 -0.823303
# Average Waiting Time Simple         1.473130          2.343788 -0.870658
# Average Waiting Time Complex        1.998337          2.607806 -0.609468
# Average Waiting Time Queue 1        1.264778          2.049524 -0.784745
# Average Waiting Time Queue 2        2.224329          2.945383 -0.721054
# Average Queue Length 1             12.954194         16.979179 -4.024985
# Average Queue Length 2             13.437240         17.195122 -3.757882
#
# Comparison of Metrics Between Policies (One Month):
#                               Optimal Policy  Generated Policy     Delta
# Metric
# Average Waiting Time                2.131895          2.579834 -0.447939
# Average Service Time                0.140912          0.153741 -0.012829
# Average Total Time                  2.272807          2.733575 -0.460769
# Average Waiting Time Simple         1.988124          2.519416 -0.531293
# Average Waiting Time Complex        2.482179          2.724022 -0.241843
# Average Waiting Time Queue 1        1.711748          2.232010 -0.520262
# Average Waiting Time Queue 2        2.810011          3.051186 -0.241175
# Average Queue Length 1             15.916250         17.720000 -1.803750
# Average Queue Length 2             16.204722         17.894583 -1.689861

# %%
def volume_df(results_a, results_b):
    """Create a volume comparison DataFrame for two sets of results."""
    df = pd.DataFrame({
        'Metric': ['Total Calls', 'Completed Calls',
                'Agent 1 Calls', 'Agent 2 Calls', 'Dropped Calls'],
        'Optimal Policy': [results_a['call_counts']['total'], results_a['call_counts']['completed'],
                        results_a['call_counts']['agent1'], results_a['call_counts']['agent2'],
                        results_a['call_counts']['dropped']],
        'Generated Policy': [results_b['call_counts']['total'], results_b['call_counts']['completed'],
                            results_b['call_counts']['agent1'], results_b['call_counts']['agent2'],
                            results_b['call_counts']['dropped']]
    })
    df.set_index('Metric', inplace=True)
    df['Delta'] = df['Optimal Policy'] - df['Generated Policy']
    
    return df

# %%
# Compare call volumes between the two policies
call_volume_day = volume_df(results, results_2)
call_volume_week = volume_df(results_week, results_week_2)
call_volume_month = volume_df(results_month, results_month_2)

# Display the call volume comparison
print("\nComparison of Call Volumes Between Policies (One Day):")
print(call_volume_day)
print("\nComparison of Call Volumes Between Policies (One Week):")
print(call_volume_week)
print("\nComparison of Call Volumes Between Policies (One Month):")
print(call_volume_month)
# Out:
# Comparison of Call Volumes Between Policies (One Day):
#                  Optimal Policy  Generated Policy  Delta
# Metric
# Total Calls                 356               361     -5
# Completed Calls             356               346     10
# Agent 1 Calls               224               198     26
# Agent 2 Calls               132               148    -16
# Dropped Calls                 0                15    -15
#
# Comparison of Call Volumes Between Policies (One Week):
#                  Optimal Policy  Generated Policy  Delta
# Metric
# Total Calls                2758              2825    -67
# Completed Calls            2514              2215    299
# Agent 1 Calls              1591              1300    291
# Agent 2 Calls               923               915      8
# Dropped Calls               244               610   -366
#
# Comparison of Call Volumes Between Policies (One Month):
#                  Optimal Policy  Generated Policy  Delta
# Metric
# Total Calls               12103             12154    -51
# Completed Calls           10158              9357    801
# Agent 1 Calls              6272              5384    888
# Agent 2 Calls              3886              3973    -87
# Dropped Calls              1945              2797   -852
